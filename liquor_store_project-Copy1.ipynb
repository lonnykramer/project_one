# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json
import glob, os

# Google developer API key
from config import yelpkey

# %%
# Output File (CSV)

stl_zip_codes = "STL_zipcodesCORRECT.csv"

stl_zip_df = pd.read_csv(stl_zip_codes)
stl_zip_df.head()
# Out:
#    ZIP  Code   Type    County Population   Area Code(s)  Unnamed: 7  \
# 0  ZIP  Code  63101  Standard      Saint  Louis    City        2620
# 1  ZIP  Code  63102  Standard      Saint  Louis    City        2316
# 2  ZIP  Code  63103  Standard      Saint  Louis    City        6900
# 3  ZIP  Code  63104  Standard      Saint  Louis    City       18656
# 4  ZIP  Code  63106  Standard      Saint  Louis    City       11883
#
#    Unnamed: 8
# 0         314
# 1         314
# 2         314
# 3         314
# 4         314

# %%
stl_zip_df.drop(['ZIP', 'Code', 'County', 'Population', 'Area', 'Code(s)', 'Unnamed: 8'], axis=1, inplace=True)
stl_zip_df.head()
# Out:
#     Type  Unnamed: 7
# 0  63101        2620
# 1  63102        2316
# 2  63103        6900
# 3  63104       18656
# 4  63106       11883

# %%
stl_zip_df = stl_zip_df.rename(columns={"Type": "ZIP Code", "Unnamed: 7": "Population"})
stl_zip_df.head()
# Out:
#    ZIP Code  Population
# 0     63101        2620
# 1     63102        2316
# 2     63103        6900
# 3     63104       18656
# 4     63106       11883

# %%
stl_zip_df.dtypes
# Out:
# ZIP Code      int64
# Population    int64
# dtype: object

# %%
zip_codes = stl_zip_df['ZIP Code']
#zip_codes

# %%
# importing crime data (CSV) and combining into 1 df

stl_crime_df = pd.concat(map(pd.read_csv, glob.glob(os.path.join("complete_file.csv"))))
stl_crime_df.head()
# Out:
#    Complaint CodedMonth        DateOccur FlagCrime FlagUnfounded  \
# 0  19-025935    2019-06    1/1/1900 0:00         Y
# 1  19-020007    2019-05   6/18/1994 0:01         Y
# 2  19-010094    2019-03   2/7/1996 13:02         Y
# 3  19-007109    2019-02  10/7/1996 12:43         Y
# 4  19-028394    2019-06   7/5/1998 12:00         Y
#
#   FlagAdministrative  Count FlagCleanup   Crime  District  ... LocationName  \
# 0                         1               51322         4  ...
# 1                         1              175500         1  ...
# 2                         1              263899         4  ...
# 3                         1              263899         4  ...
# 4                         1              115400         6  ...
#
#   LocationComment CADAddress  CADStreet Unnamed: 18 state  \
# 0                       1811     WARREN   St. Louis    MO
# 1                       7300    VERMONT   St. Louis    MO
# 2   @HEADQUARTERS       1915      OLIVE   St. Louis    MO
# 3   @HEADQUARTERS       1915      OLIVE   St. Louis    MO
# 4                       5704       ACME   St. Louis    MO
#
#                 street address    Zip    XCoord     YCoord
# 0   1811 WARREN, St. Louis, MO  63106  898905.7  1036540.0
# 1  7300 VERMONT, St. Louis, MO  63101  892793.9  1076992.0
# 2    1915 OLIVE, St. Louis, MO  63103       0.0        0.0
# 3    1915 OLIVE, St. Louis, MO  63103       0.0        0.0
# 4     5704 ACME, St. Louis, MO  63101       0.0        0.0
#
# [5 rows x 24 columns]

# %%
stl_crime_df.drop(['FlagCrime', 'FlagUnfounded', 'FlagAdministrative', 'Count', 'FlagCleanup'], axis=1, inplace=True)
#stl_crime_df.head()

# %%
zip_code_df = pd.DataFrame(stl_crime_df["Zip"].value_counts())
zip_code_df.head()
# Out:
#          Zip
# 63101  15623
# 63116   1156
# 63118    989
# 63147    859
# 63103    779

# %%
new_zip = zip_code_df.reset_index()
clean_zip = new_zip.rename(columns={"index": "ZIP Code", "Zip": "Crimes Committed"})
clean_zip.head()
# Out:
#    ZIP Code  Crimes Committed
# 0     63101             15623
# 1     63116              1156
# 2     63118               989
# 3     63147               859
# 4     63103               779

# %%
crime_merge = pd.merge(clean_zip, stl_zip_df, on="ZIP Code", how="outer")
crime_merge
# Out:
#     ZIP Code  Crimes Committed  Population
# 0      63101           15623.0      2620.0
# 1      63116            1156.0     43540.0
# 2      63118             989.0     26704.0
# 3      63147             859.0     11373.0
# 4      63103             779.0      6900.0
# 5      63111             748.0     20313.0
# 6      63104             666.0     18656.0
# 7      63107             650.0     11912.0
# 8      63115             638.0     20775.0
# 9      63112             574.0     20368.0
# 10     63113             545.0     13167.0
# 11     63110             524.0     17107.0
# 12     63106             521.0     11883.0
# 13     63108             489.0     21568.0
# 14     63102             468.0      2316.0
# 15     63120             429.0     10296.0
# 16     63109             357.0     26946.0
# 17     63125             330.0         NaN
# 18     63139             302.0     22789.0
# 19     63129             267.0         NaN
# 20     63136             173.0         NaN
# 21     63141              94.0         NaN
# 22     63137              87.0         NaN
# 23     63132              71.0         NaN
# 24     63134              56.0         NaN
# 25     63143              50.0         NaN
# 26     63044              47.0         NaN
# 27     63123              45.0         NaN
# 28     63119              37.0         NaN
# 29     63122              37.0         NaN
# 30     63117              32.0         NaN
# 31     63131              22.0         NaN
# 32     63121              20.0         NaN
# 33     63130              20.0         NaN
# 34     63138              18.0         NaN
# 35     63135              13.0         NaN
# 36     63133               6.0         NaN
# 37     63105               5.0         NaN
# 38     63146               4.0         NaN
# 39     63031               4.0         NaN
# 40     63128               4.0         NaN
# 41     63144               4.0         NaN
# 42     63367               4.0         NaN
# 43     63142               4.0         NaN
# 44     63011               2.0         NaN
# 45     63074               1.0         NaN
# 46     63033               1.0         NaN
# 47     63025               1.0         NaN
# 48     63127               1.0         NaN
# 49     63150               NaN         0.0
# 50     63155               NaN         0.0
# 51     63160               NaN         0.0
# 52     63164               NaN         0.0
# 53     63171               NaN         0.0
# 54     63180               NaN         0.0
# 55     63182               NaN         0.0
# 56     63195               NaN         0.0
# 57     63197               NaN         0.0
# 58     63199               NaN         0.0

# %%
clean_zip_df = crime_merge.dropna(subset=['Crimes Committed', 'Population'])
clean_zip_df
# Out:
#     ZIP Code  Crimes Committed  Population
# 0      63101           15623.0      2620.0
# 1      63116            1156.0     43540.0
# 2      63118             989.0     26704.0
# 3      63147             859.0     11373.0
# 4      63103             779.0      6900.0
# 5      63111             748.0     20313.0
# 6      63104             666.0     18656.0
# 7      63107             650.0     11912.0
# 8      63115             638.0     20775.0
# 9      63112             574.0     20368.0
# 10     63113             545.0     13167.0
# 11     63110             524.0     17107.0
# 12     63106             521.0     11883.0
# 13     63108             489.0     21568.0
# 14     63102             468.0      2316.0
# 15     63120             429.0     10296.0
# 16     63109             357.0     26946.0
# 18     63139             302.0     22789.0

# %%
clean_zip_df.sum()
# Out:
# ZIP Code            1136041.0
# Crimes Committed      26317.0
# Population           309233.0
# dtype: float64

# %%
lat_long = pd.read_csv("lat_long_zip.csv")
lat_long.drop(['City'], axis=1, inplace=True)
lat_long = lat_long.dropna(subset=['Latitude','Longitude','Zip'])
lat_long['Zip']=lat_long['Zip'].astype(int)
lat_long = lat_long.rename(columns={"Zip": "ZIP Code"})
lat_long
# Out:
#      Latitude  Longitude              geopoint  ZIP Code
# 0   38.631551  -90.19300    38.631551, -90.193     63101
# 1   38.635200  -90.18702    38.6352, -90.18702     63102
# 2   38.631451  -90.21415  38.631451, -90.21415     63103
# 3   38.610701  -90.21362  38.610701, -90.21362     63104
# 4   38.644451  -90.20636  38.644451, -90.20636     63106
# 5   38.662800  -90.20949    38.6628, -90.20949     63107
# 6   38.646201  -90.25435  38.646201, -90.25435     63108
# 7   38.586052  -90.29410   38.586052, -90.2941     63109
# 8   38.622601  -90.26182  38.622601, -90.26182     63110
# 9   38.559302  -90.25174  38.559302, -90.25174     63111
# 10  38.661351  -90.28434  38.661351, -90.28434     63112
# 11  38.656701  -90.24397  38.656701, -90.24397     63113
# 12  38.676851  -90.24009  38.676851, -90.24009     63115
# 13  38.580552  -90.26307  38.580552, -90.26307     63116
# 14  38.594901  -90.22780   38.594901, -90.2278     63118
# 15  38.691901  -90.25992  38.691901, -90.25992     63120
# 16  38.610901  -90.29174  38.610901, -90.29174     63139
# 17  38.692861  -90.21905  38.692861, -90.21905     63147

# %%
lat_long.dtypes
final_df = pd.merge(clean_zip_df,lat_long, on="ZIP Code", how="outer")
final_df
# Out:
#     ZIP Code  Crimes Committed  Population   Latitude  Longitude  \
# 0      63101           15623.0      2620.0  38.631551  -90.19300
# 1      63116            1156.0     43540.0  38.580552  -90.26307
# 2      63118             989.0     26704.0  38.594901  -90.22780
# 3      63147             859.0     11373.0  38.692861  -90.21905
# 4      63103             779.0      6900.0  38.631451  -90.21415
# 5      63111             748.0     20313.0  38.559302  -90.25174
# 6      63104             666.0     18656.0  38.610701  -90.21362
# 7      63107             650.0     11912.0  38.662800  -90.20949
# 8      63115             638.0     20775.0  38.676851  -90.24009
# 9      63112             574.0     20368.0  38.661351  -90.28434
# 10     63113             545.0     13167.0  38.656701  -90.24397
# 11     63110             524.0     17107.0  38.622601  -90.26182
# 12     63106             521.0     11883.0  38.644451  -90.20636
# 13     63108             489.0     21568.0  38.646201  -90.25435
# 14     63102             468.0      2316.0  38.635200  -90.18702
# 15     63120             429.0     10296.0  38.691901  -90.25992
# 16     63109             357.0     26946.0  38.586052  -90.29410
# 17     63139             302.0     22789.0  38.610901  -90.29174
#
#                 geopoint
# 0     38.631551, -90.193
# 1   38.580552, -90.26307
# 2    38.594901, -90.2278
# 3   38.692861, -90.21905
# 4   38.631451, -90.21415
# 5   38.559302, -90.25174
# 6   38.610701, -90.21362
# 7     38.6628, -90.20949
# 8   38.676851, -90.24009
# 9   38.661351, -90.28434
# 10  38.656701, -90.24397
# 11  38.622601, -90.26182
# 12  38.644451, -90.20636
# 13  38.646201, -90.25435
# 14    38.6352, -90.18702
# 15  38.691901, -90.25992
# 16   38.586052, -90.2941
# 17  38.610901, -90.29174

# %%
# **************************

# Brooklyn code:
#r=requests.get("https://api.yelp.com/v3/businesses/search", headers={"content-type":"Bearer"})

url = "https://api.yelp.com/v3/businesses/search"

for page_num in [1, 2]:
    purl = "https://api.yelp.com/v3/businesses/search" + str(page_num)
    print(purl)

addresses_df = pd.read_csv("addresszip.csv")



store_names = []
loc_zip_codes =[]
stl_zip_codes =[]

zips = {
    63101,
    63102,
    63103,
    63104,
    63106,
    63107,
    63108,
    63109,
    63110,
    63111,
    63112,
    63113,
    63115,
    63116,
    63118,
    63120,
    63139,
    63147,
    
}


unique_zip_codes = addresses_df["Zip"].unique()


#for zip_code in ["63101","63102","63103","63104", "63106","63107", 
#                  "63108","63109", "63110","63111", "63112","63113",
#                  "63115","63116", "63118","63120", "63139","63147"]:

for index, row in final_df.iterrows():
#for zip_code in zip_codes:
#for zip_code in zips:
    zip_code = str(int(row['ZIP Code']))
    print(zip_code)
    params = {
        "Authorization": yelpkey,
        "latitude":    row['Latitude'],
        "longitude":    row['Longitude'],
        #"location": zip_code,
        "categories": "beer_and_wine,servicestations",
        "sort_by": "distance",
        "limit": "50",
        "radius": 5000
    }

    response = requests.get(url, params=params, headers={"Authorization": f"Bearer {yelpkey}"})
    
    data = response.json()
    print(f'input zip {zip_code} length {len(data["businesses"])}')
    
    for store in data["businesses"]:
        loc_zip = store["location"]["zip_code"]
        store_name = store["name"]
#         if loc_zip == zip_code:
        loc_zip_codes.append(loc_zip)
        store_names.append(store_name)
        stl_zip_codes.append(zip_code)
        
        
#         combined_stores.append(pd.Series([loc_data,name_data],index=["Zip Code","Store Name"]),ignore_index=True)
        
        
    
combined_stores_df = pd.DataFrame({"STL Zip Code":stl_zip_codes ,"Store Name": store_names, "Store Zip Code": loc_zip_codes})
combined_stores_df

#zip_code = "63115"

# response = requests.get(url, params=params, headers={"Authorization": f"Bearer {yelpkey}"})
# response
#unique_zip_codes
# Out:
# https://api.yelp.com/v3/businesses/search1
# https://api.yelp.com/v3/businesses/search2
# 63101
# input zip 63101 length 34
# 63116
# input zip 63116 length 45
# 63118
# input zip 63118 length 48
# 63147
# input zip 63147 length 15
# 63103
# input zip 63103 length 43
# 63111
# input zip 63111 length 28
# 63104
# input zip 63104 length 42
# 63107
# input zip 63107 length 32
# 63115
# input zip 63115 length 26
# 63112
# input zip 63112 length 46
# 63113
# input zip 63113 length 45
# 63110
# input zip 63110 length 44
# 63106
# input zip 63106 length 38
# 63108
# input zip 63108 length 47
# 63102
# input zip 63102 length 33
# 63120
# input zip 63120 length 17
# 63109
# input zip 63109 length 50
# 63139
# input zip 63139 length 50
#     STL Zip Code                                Store Name Store Zip Code
# 0          63101                                     Yoshi          63101
# 1          63101                                     Shell          63101
# 2          63101                    James Henry Provisions          63102
# 3          63101                          Crown Mart 7 Inc          63106
# 4          63101                                  Kilroy's          63102
# 5          63101                         Overturf Bp Amoco          63102
# 6          63101                                        BP          63103
# 7          63101                       Grand Petite Market          63103
# 8          63101                                        BP          63103
# 9          63101                         Midwest Petroleum          63103
# 10         63101                        33 Wine Shop & Bar          63104
# 11         63101                                 The Porch          63104
# 12         63101                                  QuikTrip          63103
# 13         63101  1860 Saloon, Game Room, & Hardshell Café          63104
# 14         63101           One-Stop Mini-Mart & Pkg Liquor          63103
# 15         63101                                Globe Drug          63104
# 16         63101                                Compton Bp          63103
# 17         63101                          Marketing Energy          63104
# 18         63101                Midwest Petroleum - Conoco          63104
# 19         63101                               Phillips 66          63104
# 20         63101                Randall's Wine and Spirits          63104
# 21         63101                      Billiken Field House          63103
# 22         63101                                   Safa Bp          63107
# 23         63101                                  Circle K          63103
# 24         63101                               Mobile Mart          63107
# 25         63101                    Joel's Shell Food Mart          63118
# 26         63101                                  QuikTrip          63118
# 27         63101              Energy Express Travel Center          63147
# 28         63101                 Jefferson B P Gas Station          63118
# 29         63101                                      Foam          63118
# ..           ...                                       ...            ...
# 653        63139                                    D Mart          63143
# 654        63139                          Giant Amoco Sign          63117
# 655        63139               Stevenson's Hi-Pointe Amoco          63105
# 656        63139                      Schaefer's Auto Care          63143
# 657        63139                                  QuikTrip          63143
# 658        63139                     Local Harvest Grocery          63116
# 659        63139                               Phillips 66          63109
# 660        63139           Kingshighway & Manchester Amoco          63110
# 661        63139                           In & Out Market          63117
# 662        63139                            Parker's Table          63117
# 663        63139                                Fowler' ZX          63117
# 664        63139                                    Starrs          63117
# 665        63139                              Intoxicology          63110
# 666        63139                     Bruce's Mobil Service          63117
# 667        63139                                     U-Gas          63143
# 668        63139                               Philipps 66          63143
# 669        63139                          Waterway Carwash          63119
# 670        63139                         Dierbergs Markets          63119
# 671        63139                            Gustine Market          63116
# 672        63139                                  QuikTrip          63116
# 673        63139                                  QuikTrip          63144
# 674        63139                                  Gas Mart          63109
# 675        63139                      A & Z Package Liquor          63108
# 676        63139                                        BP          63108
# 677        63139                          Shapiro's Market          63108
# 678        63139                                  QuikTrip          63116
# 679        63139                               Phillips 66          63108
# 680        63139                               STLwinegirl          63105
# 681        63139                             Mel's Service          63116
# 682        63139                   The Wine & Cheese Place          63105
#
# [683 rows x 3 columns]

# %%
zip_count_df = combined_stores_df.groupby(['STL Zip Code']).size().reset_index(name='counts')
zip_count_df = zip_count_df.rename(columns={"STL Zip Code": "ZIP Code", "counts": "Liquor Stores"})
zip_count_df
# Out:
#    ZIP Code  Liquor Stores
# 0     63101             34
# 1     63102             33
# 2     63103             43
# 3     63104             42
# 4     63106             38
# 5     63107             32
# 6     63108             47
# 7     63109             50
# 8     63110             44
# 9     63111             28
# 10    63112             46
# 11    63113             45
# 12    63115             26
# 13    63116             45
# 14    63118             48
# 15    63120             17
# 16    63139             50
# 17    63147             15

# %%
data = response.json()
pprint(data)
# Out:
# {'businesses': [{'alias': 'hampton-express-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'convenience',
#                                  'title': 'Convenience Stores'}],
#                  'coordinates': {'latitude': 38.609989,
#                                  'longitude': -90.288498},
#                  'display_phone': '',
#                  'distance': 299.0010063961226,
#                  'id': 'RAGxjLd21aGJHTnjiz3m3A',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '2724 Watson Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['2724 Watson Rd',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'Hampton Express',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hampton-express-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'quiktrip-st-louis-7',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'convenience',
#                                  'title': 'Convenience Stores'}],
#                  'coordinates': {'latitude': 38.6156429,
#                                  'longitude': -90.2866168},
#                  'display_phone': '(314) 645-7184',
#                  'distance': 690.0422589686732,
#                  'id': 'jM4xHqyMWjZ5LG9DxT8vaQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lBQs4D_jcPlHzG1xQ7PSCg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2166 Hampton Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'St Louis',
#                               'country': 'US',
#                               'display_address': ['2166 Hampton Ave',
#                                                   'St Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'QuikTrip',
#                  'phone': '+13146457184',
#                  'price': '$',
#                  'rating': 3.0,
#                  'review_count': 4,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/quiktrip-st-louis-7?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'u-gas-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'carwash', 'title': 'Car Wash'}],
#                  'coordinates': {'latitude': 38.60387, 'longitude': -90.292},
#                  'display_phone': '(314) 644-4491',
#                  'distance': 769.6207306632419,
#                  'id': 'pKxOXAuC1i8mnUjxVW2tnQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HhRUM56qprJjN8vjtag8QA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3225 Hampton Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['3225 Hampton Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'U Gas',
#                  'phone': '+13146444491',
#                  'rating': 4.5,
#                  'review_count': 15,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/u-gas-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': '7-eleven-saint-louis-20',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 38.6133662519629,
#                                  'longitude': -90.3082527127299},
#                  'display_phone': '(314) 644-0711',
#                  'distance': 1460.6815127861223,
#                  'id': 'oRY9axuwOQSN4HbTu7obtg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qeMbat2QpMvEIaBNZTpJqA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6909 Southwest Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['6909 Southwest Ave',
#                                                   'Saint Louis, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': '7-Eleven',
#                  'phone': '+13146440711',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 4,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/7-eleven-saint-louis-20?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'circle-k-saint-louis-29',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.62368, 'longitude': -90.28743},
#                  'display_phone': '(314) 646-7617',
#                  'distance': 1472.0150999934951,
#                  'id': 'Bd-jqcAp2OS5N837BRqDyA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LK4H5el9L0np8ugAr1IhsA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1514 Hampton Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['1514 Hampton Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'Circle K',
#                  'phone': '+13146467617',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 4,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/circle-k-saint-louis-29?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'circle-k-saint-louis-22',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.612698,
#                                  'longitude': -90.309596},
#                  'display_phone': '(314) 646-7653',
#                  'distance': 1562.5738250888714,
#                  'id': 'VF6lvdUGdC8GcfmAWMVLww',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j2l6ZLH0gYrs2eoVTFMAXw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2707 McCausland Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['2707 McCausland Ave',
#                                                   'Saint Louis, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': 'Circle K',
#                  'phone': '+13146467653',
#                  'price': '$$',
#                  'rating': 2.0,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/circle-k-saint-louis-22?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'gas-mart-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.603896,
#                                  'longitude': -90.307203},
#                  'display_phone': '(314) 781-0434',
#                  'distance': 1564.69465068721,
#                  'id': '9rt8onwFcfoMWFe6Mq8mHA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/viT-bJ9lA1bIdU8jBBdeAQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3282 Jamieson Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['3282 Jamieson Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'Gas Mart',
#                  'phone': '+13147810434',
#                  'rating': 2.0,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gas-mart-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'circle-k-saint-louis-34',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.603896,
#                                  'longitude': -90.307203},
#                  'display_phone': '(314) 646-8145',
#                  'distance': 1564.69465068721,
#                  'id': 'jBWoPQgpRo9L8AwSnGgYpA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FZ6w1t28ILYrxkT4DaGIhA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3282 Jamieson Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['3282 Jamieson Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'Circle K',
#                  'phone': '+13146468145',
#                  'rating': 3.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/circle-k-saint-louis-34?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'mccausland-auto-center-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.6166337,
#                                  'longitude': -90.3092489},
#                  'display_phone': '(314) 647-0366',
#                  'distance': 1673.6741226643599,
#                  'id': 'BEIh71n5FHv-sMp-1jJCvA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sPXxZK2x-cUzGx7t9Z5-kQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7003 Manchester Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['7003 Manchester Ave',
#                                                   'Saint Louis, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': 'McCausland Auto Center',
#                  'phone': '+13146470366',
#                  'rating': 3.0,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mccausland-auto-center-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'the-third-rail-st-louis',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 38.6234049933554,
#                                  'longitude': -90.280940673618},
#                  'display_phone': '(314) 833-4323',
#                  'distance': 1677.338211763736,
#                  'id': 'BV00Q5bw1pHcBY2zHyMMyA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tqPrWlpQ1VZgk43qraF67Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5625 Manchester Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'St. Louis',
#                               'country': 'US',
#                               'display_address': ['5625 Manchester Ave',
#                                                   'St. Louis, MO 63110'],
#                               'state': 'MO',
#                               'zip_code': '63110'},
#                  'name': 'The Third Rail',
#                  'phone': '+13148334323',
#                  'rating': 4.5,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-third-rail-st-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'patricks-dogtown-liquors-saint-louis',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.626922,
#                                  'longitude': -90.293319},
#                  'display_phone': '(314) 645-6327',
#                  'distance': 1802.6100029136837,
#                  'id': 'O_Dku_GhruN_RJxfCJqFBw',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '6400 W Park Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['6400 W Park Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': "Patrick's Dogtown Liquors",
#                  'phone': '+13146456327',
#                  'price': '$',
#                  'rating': 3.0,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/patricks-dogtown-liquors-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'arena-liquor-saint-louis-2',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.627872467041,
#                                  'longitude': -90.2877426147461},
#                  'display_phone': '(314) 645-6644',
#                  'distance': 1913.092755055315,
#                  'id': 'eNplYNNQP9TIWVzejwIHow',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tThc5A5XYn2CVGdeDO5HeA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1217 Hampton Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['1217 Hampton Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'Arena Liquor',
#                  'phone': '+13146456644',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 19,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/arena-liquor-saint-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'maplewood-liquor-saint-louis',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.6143226623535,
#                                  'longitude': -90.314338684082},
#                  'display_phone': '(314) 645-5731',
#                  'distance': 1989.5770061884243,
#                  'id': 'iuhnsFMO-7JZYP1-YPc-YA',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '7203 Manchester Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['7203 Manchester Rd',
#                                                   'Saint Louis, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': 'Maplewood Liquor',
#                  'phone': '+13146455731',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/maplewood-liquor-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'craft-beer-cellar-st-louis',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.59285, 'longitude': -90.29144},
#                  'display_phone': '(314) 222-0333',
#                  'distance': 2009.2721365344073,
#                  'id': 'YJWTfg39ZiOcs5VCBCzBlQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gUhtFV42pgqrtpG2v7RXUQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5760 Chippewa St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'St. Louis',
#                               'country': 'US',
#                               'display_address': ['5760 Chippewa St',
#                                                   'St. Louis, MO 63109'],
#                               'state': 'MO',
#                               'zip_code': '63109'},
#                  'name': 'Craft Beer Cellar',
#                  'phone': '+13142220333',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 21,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/craft-beer-cellar-st-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'bp-saint-louis-6',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.629135,
#                                  'longitude': -90.286842},
#                  'display_phone': '(314) 646-1600',
#                  'distance': 2063.8644027785476,
#                  'id': 'yqdtL9OUH-MMu891tx7Yng',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cmdk0LqNTRTXF0x6gju5sA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1104 Hampton Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['1104 Hampton Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'BP',
#                  'phone': '+13146461600',
#                  'price': '$$$',
#                  'rating': 2.0,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bp-saint-louis-6?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'the-full-package-saint-louis-2',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.6291389,
#                                  'longitude': -90.2868423},
#                  'display_phone': '(314) 646-1600',
#                  'distance': 2088.1191581285,
#                  'id': 'IXe8BK4gcB_3gvsLn9dYkA',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '1104 Hampton Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['1104 Hampton Ave',
#                                                   'Saint Louis, MO 63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'The Full Package',
#                  'phone': '+13146461600',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-full-package-saint-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'bp-saint-louis-7',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.6131051339787,
#                                  'longitude': -90.2672960086596},
#                  'display_phone': '',
#                  'distance': 2137.9469404586434,
#                  'id': 'DO-V5ssq9CoFO3FFGoU-yQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XFftxzMYUtXJXn-GD50Dmw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1187 S Kingshighway',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['1187 S Kingshighway',
#                                                   'Saint Louis, MO 63110'],
#                               'state': 'MO',
#                               'zip_code': '63110'},
#                  'name': 'BP',
#                  'phone': '',
#                  'rating': 3.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bp-saint-louis-7?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'quiktrip-st-louis-downtown-10',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'convenience',
#                                  'title': 'Convenience Stores'}],
#                  'coordinates': {'latitude': 38.6004971,
#                                  'longitude': -90.2705598},
#                  'display_phone': '(314) 351-4600',
#                  'distance': 2173.8270632134654,
#                  'id': 'd26K8f4sHEl8Pvct59OISQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7NKTj2ruICzGAApej7KlHQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3291 S Kingshighway Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'St Louis Downtown',
#                               'country': 'US',
#                               'display_address': ['3291 S Kingshighway Blvd',
#                                                   'St Louis Downtown, MO '
#                                                   '63139'],
#                               'state': 'MO',
#                               'zip_code': '63139'},
#                  'name': 'QuikTrip',
#                  'phone': '+13143514600',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 9,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/quiktrip-st-louis-downtown-10?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'vom-fass-maplewood',
#                  'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.6128768920898,
#                                  'longitude': -90.3176345825195},
#                  'display_phone': '(314) 932-5262',
#                  'distance': 2264.9388303237874,
#                  'id': 'qQSscPMhk3frtSNilF1cGA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CzqL-ldFvbjQwWxHhwFZ7w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7314 Manchester Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Maplewood',
#                               'country': 'US',
#                               'display_address': ['7314 Manchester Rd',
#                                                   'Maplewood, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': 'VOM FASS',
#                  'phone': '+13149325262',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 63,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/vom-fass-maplewood?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'chateau-maplewood-maplewood-2',
#                  'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.61274, 'longitude': -90.31815},
#                  'display_phone': '(314) 899-0105',
#                  'distance': 2309.5377788154688,
#                  'id': '8iAkAm5TPHvrfIKs33lTNA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bihhtC2XCee-KwL2lXO9-Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7326 Manchester Rd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Maplewood',
#                               'country': 'US',
#                               'display_address': ['7326 Manchester Rd',
#                                                   'Maplewood, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': 'Chateau Maplewood',
#                  'phone': '+13148990105',
#                  'rating': 5.0,
#                  'review_count': 10,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chateau-maplewood-maplewood-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'd-mart-maplewood',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.61312, 'longitude': -90.32254},
#                  'display_phone': '(314) 644-0497',
#                  'distance': 2679.830429584782,
#                  'id': '-0A78nLURx8zQmlZxad0lg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n4VQBofe0cAjhLU9yq_D5g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2664 S Big Bend Blvd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Maplewood',
#                               'country': 'US',
#                               'display_address': ['2664 S Big Bend Blvd',
#                                                   'Maplewood, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': 'D Mart',
#                  'phone': '+13146440497',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/d-mart-maplewood?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'giant-amoco-sign-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'landmarks',
#                                  'title': 'Landmarks & Historical Buildings'}],
#                  'coordinates': {'latitude': 38.63317, 'longitude': -90.30495},
#                  'display_phone': '',
#                  'distance': 2719.431797161311,
#                  'id': '1jSL90jj7k95OsSaQL5O-A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iPdEAmpDQmhBuhwBju-vRQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '981 S Skinker Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['981 S Skinker Blvd',
#                                                   'Saint Louis, MO 63117'],
#                               'state': 'MO',
#                               'zip_code': '63117'},
#                  'name': 'Giant Amoco Sign',
#                  'phone': '',
#                  'rating': 4.5,
#                  'review_count': 31,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/giant-amoco-sign-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'stevensons-hi-pointe-amoco-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.63317, 'longitude': -90.30495},
#                  'display_phone': '(314) 647-5005',
#                  'distance': 2719.431797161311,
#                  'id': 'UckNEwdwns8ONOsV52Py3A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ixyhac-OZip-T77tjZ5erw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '981 S Skinker Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['981 S Skinker Blvd',
#                                                   'Saint Louis, MO 63105'],
#                               'state': 'MO',
#                               'zip_code': '63105'},
#                  'name': "Stevenson's Hi-Pointe Amoco",
#                  'phone': '+13146475005',
#                  'rating': 4.5,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/stevensons-hi-pointe-amoco-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'schaefers-auto-care-saint-louis-2',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'autorepair',
#                                  'title': 'Auto Repair'}],
#                  'coordinates': {'latitude': 38.61207, 'longitude': -90.3235},
#                  'display_phone': '(314) 647-7850',
#                  'distance': 2761.4207207906647,
#                  'id': 'AhkxM49Z15NoLNoHnSELMw',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '2707 S Big Bend Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['2707 S Big Bend Blvd',
#                                                   'Saint Louis, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': "Schaefer's Auto Care",
#                  'phone': '+13146477850',
#                  'rating': 3.5,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/schaefers-auto-care-saint-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'quiktrip-maplewood-3',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'convenience',
#                                  'title': 'Convenience Stores'}],
#                  'coordinates': {'latitude': 38.613414,
#                                  'longitude': -90.323373},
#                  'display_phone': '(314) 647-7114',
#                  'distance': 2762.642291644319,
#                  'id': 'oSgio-JgXNsqKx9CXZ0YUg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K0eYyepckGu7F2HMtNv7tg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2633 S Big Bend Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Maplewood',
#                               'country': 'US',
#                               'display_address': ['2633 S Big Bend Blvd',
#                                                   'Maplewood, MO 63143'],
#                               'state': 'MO',
#                               'zip_code': '63143'},
#                  'name': 'QuikTrip',
#                  'phone': '+13146477114',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 11,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/quiktrip-maplewood-3?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'local-harvest-grocery-saint-louis',
#                  'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#                                 {'alias': 'gourmet', 'title': 'Specialty Food'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.604148,
#                                  'longitude': -90.261073},
#                  'display_phone': '(314) 865-5260',
#                  'distance': 2768.492240833826,
#                  'id': 'F6HCLpKegKxE6g1jyUaqiQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GfU6RFt10ZdWoFx4aQE0Sw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3108 Morgan Ford Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['3108 Morgan Ford Rd',
#                                                   'Saint Louis, MO 63116'],
#                               'state': 'MO',
#                               'zip_code': '63116'},
#                  'name': 'Local Harvest Grocery',
#                  'phone': '+13148655260',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 53,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/local-harvest-grocery-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'phillips-66-saint-louis-14',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.5898368529038,
#                                  'longitude': -90.273999912042},
#                  'display_phone': '(314) 481-3157',
#                  'distance': 2804.0355681824544,
#                  'id': 'tJ236kyCeZjqf9gWrVLRnA',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '4300 S Kingshighway Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['4300 S Kingshighway Blvd',
#                                                   'Saint Louis, MO 63109'],
#                               'state': 'MO',
#                               'zip_code': '63109'},
#                  'name': 'Phillips 66',
#                  'phone': '+13144813157',
#                  'rating': 1.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/phillips-66-saint-louis-14?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'kingshighway-and-manchester-amoco-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.62611,
#                                  'longitude': -90.2653799},
#                  'display_phone': '(314) 531-2525',
#                  'distance': 2830.705399999117,
#                  'id': 'Jtxr-1x5epjJW05RXOpjPQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/l4eF-FJxCcp8eVkv1c11Tg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1187 S Kingshighway Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['1187 S Kingshighway Blvd',
#                                                   'Saint Louis, MO 63110'],
#                               'state': 'MO',
#                               'zip_code': '63110'},
#                  'name': 'Kingshighway & Manchester Amoco',
#                  'phone': '+13145312525',
#                  'rating': 3.0,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kingshighway-and-manchester-amoco-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'in-and-out-market-richmond-heights',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 38.630621,
#                                  'longitude': -90.312564},
#                  'display_phone': '(314) 647-2696',
#                  'distance': 2842.720047731152,
#                  'id': 'EPiFB9rj-RXf8VHdpVV67A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oXKMVKVUaWpGfPlAVvbW8g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1133 Bellevue Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Richmond Heights',
#                               'country': 'US',
#                               'display_address': ['1133 Bellevue Ave',
#                                                   'Richmond Heights, MO 63117'],
#                               'state': 'MO',
#                               'zip_code': '63117'},
#                  'name': 'In & Out Market',
#                  'phone': '+13146472696',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 16,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/in-and-out-market-richmond-heights?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'parkers-table-saint-louis-3',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'},
#                                 {'alias': 'gourmet',
#                                  'title': 'Specialty Food'}],
#                  'coordinates': {'latitude': 38.632946,
#                                  'longitude': -90.308952},
#                  'display_phone': '(314) 645-2050',
#                  'distance': 2871.5922419521935,
#                  'id': 'MSVZaUMtfPr4q8lFsiu-Cg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xENxthz8i8b_NZAN3Tv6Tg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7118 Oakland Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['7118 Oakland Ave',
#                                                   'Saint Louis, MO 63117'],
#                               'state': 'MO',
#                               'zip_code': '63117'},
#                  'name': "Parker's Table",
#                  'phone': '+13146452050',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 60,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/parkers-table-saint-louis-3?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'fowler-zx-richmond-heights',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.630291,
#                                  'longitude': -90.3191376},
#                  'display_phone': '(314) 647-8472',
#                  'distance': 3217.5360256897143,
#                  'id': 'koyPjQVu-Vmu16niw196UA',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '1220 S Big Bend Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Richmond Heights',
#                               'country': 'US',
#                               'display_address': ['1220 S Big Bend Blvd',
#                                                   'Richmond Heights, MO 63117'],
#                               'state': 'MO',
#                               'zip_code': '63117'},
#                  'name': "Fowler' ZX",
#                  'phone': '+13146478472',
# ...
#                  'phone': '+13147761806',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/quiktrip-ellisville-3?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'quiktrip-richmond-heights-2',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.6257556,
#                                  'longitude': -90.3340788},
#                  'display_phone': '(314) 647-2332',
#                  'distance': 4032.1847076484532,
#                  'id': 'G6N5IuqIwCbLeTjWkf1Dzw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vv0Z7RUO0HUKcvuqCU0Oug/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1530 S Hanley Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Richmond Heights',
#                               'country': 'US',
#                               'display_address': ['1530 S Hanley Rd',
#                                                   'Richmond Heights, MO 63144'],
#                               'state': 'MO',
#                               'zip_code': '63144'},
#                  'name': 'QuikTrip',
#                  'phone': '+13146472332',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 11,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/quiktrip-richmond-heights-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'gas-mart-saint-louis-7',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.57385, 'longitude': -90.29516},
#                  'display_phone': '(314) 752-1089',
#                  'distance': 4120.468323824934,
#                  'id': '2clHJwhk3n7H7VDA2Hp2xQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_Pfff1Hk4CDGLY4uveWE0A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6901 Hampton Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['6901 Hampton Ave',
#                                                   'Saint Louis, MO 63109'],
#                               'state': 'MO',
#                               'zip_code': '63109'},
#                  'name': 'Gas Mart',
#                  'phone': '+13147521089',
#                  'rating': 3.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gas-mart-saint-louis-7?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'a-and-z-package-liquor-saint-louis',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.640347, 'longitude': -90.26129},
#                  'display_phone': '(314) 367-4014',
#                  'distance': 4209.23941494318,
#                  'id': 'ugRsDz1wCrDH_sqm9SZRiA',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '4571 Laclede Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['4571 Laclede Ave',
#                                                   'Saint Louis, MO 63108'],
#                               'state': 'MO',
#                               'zip_code': '63108'},
#                  'name': 'A & Z Package Liquor',
#                  'phone': '+13143674014',
#                  'price': '$',
#                  'rating': 2.5,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/a-and-z-package-liquor-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'bp-st-louis-2',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.6390170965611,
#                                  'longitude': -90.2552889358787},
#                  'display_phone': '(314) 533-3147',
#                  'distance': 4449.840333774468,
#                  'id': 'wWrLMIj0Mjzk_ZFbPBfa1g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Xs-Gs3tbedC8Mr9vXf30fw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4403 Laclede Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'St. Louis',
#                               'country': 'US',
#                               'display_address': ['4403 Laclede Ave',
#                                                   'St. Louis, MO 63108'],
#                               'state': 'MO',
#                               'zip_code': '63108'},
#                  'name': 'BP',
#                  'phone': '+13145333147',
#                  'rating': 3.5,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bp-st-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'shapiros-market-saint-louis',
#                  'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#                                 {'alias': 'delis', 'title': 'Delis'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.6405726,
#                                  'longitude': -90.2548064},
#                  'display_phone': '(314) 531-5704',
#                  'distance': 4621.702929940882,
#                  'id': 'DgLD56oDP0jMizXmgWmeug',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YuS9Ve-a0f7L2qys_o289Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '111 N Newstead Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['111 N Newstead Ave',
#                                                   'Saint Louis, MO 63108'],
#                               'state': 'MO',
#                               'zip_code': '63108'},
#                  'name': "Shapiro's Market",
#                  'phone': '+13145315704',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 38,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/shapiros-market-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'quiktrip-st-louis-downtown-8',
#                  'categories': [{'alias': 'convenience',
#                                  'title': 'Convenience Stores'},
#                                 {'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.5695115469798,
#                                  'longitude': -90.2852766695122},
#                  'display_phone': '(314) 353-8707',
#                  'distance': 4636.448175364242,
#                  'id': 'tUKNCjEwGsXxkwDuqQ6q9g',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uSB_fYA62B0YcheH6pUL7w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6900 Gravois Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'St Louis Downtown',
#                               'country': 'US',
#                               'display_address': ['6900 Gravois Ave',
#                                                   'St Louis Downtown, MO '
#                                                   '63116'],
#                               'state': 'MO',
#                               'zip_code': '63116'},
#                  'name': 'QuikTrip',
#                  'phone': '+13143538707',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/quiktrip-st-louis-downtown-8?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'phillips-66-saint-louis-8',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'},
#                                 {'alias': 'convenience',
#                                  'title': 'Convenience Stores'}],
#                  'coordinates': {'latitude': 38.64124, 'longitude': -90.25011},
#                  'display_phone': '(314) 531-0049',
#                  'distance': 4942.1982191447505,
#                  'id': 'rUljeaMnbB7Z7jje6tJRpg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0CppCXoIK-d6nU6mDbm4xQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4251 Lindell Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['4251 Lindell Blvd',
#                                                   'Saint Louis, MO 63108'],
#                               'state': 'MO',
#                               'zip_code': '63108'},
#                  'name': 'Phillips 66',
#                  'phone': '+13145310049',
#                  'rating': 3.0,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/phillips-66-saint-louis-8?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'stlwinegirl-saint-louis-2',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.6441879272461,
#                                  'longitude': -90.3283615112305},
#                  'display_phone': '(314) 808-0937',
#                  'distance': 5021.033530778911,
#                  'id': 'zjZ3ZqHHUetyuoTKjvwmEg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fLEJmWTRGohfpaPaU9s01Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': None,
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['Saint Louis, MO 63105'],
#                               'state': 'MO',
#                               'zip_code': '63105'},
#                  'name': 'STLwinegirl',
#                  'phone': '+13148080937',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/stlwinegirl-saint-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'mels-service-saint-louis',
#                  'categories': [{'alias': 'servicestations',
#                                  'title': 'Gas Stations'}],
#                  'coordinates': {'latitude': 38.5700225830078,
#                                  'longitude': -90.2647399902344},
#                  'display_phone': '(314) 481-4828',
#                  'distance': 5121.811736249036,
#                  'id': 'zDD3SZRxbvzaGouFPP-xCA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msF6CPdXfidxSnJPTMajXw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3970 Wilmington Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['3970 Wilmington Ave',
#                                                   'Saint Louis, MO 63116'],
#                               'state': 'MO',
#                               'zip_code': '63116'},
#                  'name': "Mel's Service",
#                  'phone': '+13144814828',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mels-service-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'},
#                 {'alias': 'the-wine-and-cheese-place-saint-louis',
#                  'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 38.649883,
#                                  'longitude': -90.329452},
#                  'display_phone': '(314) 727-8788',
#                  'distance': 5415.3777960013595,
#                  'id': 'bBnIv9ZRWvEatpIB-vP9sw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TqEwFWoffy9mMEivPW783Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7435 Forsyth Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Saint Louis',
#                               'country': 'US',
#                               'display_address': ['7435 Forsyth Blvd',
#                                                   'Saint Louis, MO 63105'],
#                               'state': 'MO',
#                               'zip_code': '63105'},
#                  'name': 'The Wine & Cheese Place',
#                  'phone': '+13147278788',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 53,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-wine-and-cheese-place-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA'}],
#  'region': {'center': {'latitude': 38.610901, 'longitude': -90.29174}},
#  'total': 57}

# %%
for store in data["businesses"]:
    
    print(store["location"]["zip_code"])
# Out:
# 63139
# 63139
# 63139
# 63143
# 63139
# 63143
# 63139
# 63139
# 63143
# 63110
# 63139
# 63139
# 63143
# 63109
# 63139
# 63139
# 63110
# 63139
# 63143
# 63143
# 63143
# 63117
# 63105
# 63143
# 63143
# 63116
# 63109
# 63110
# 63117
# 63117
# 63117
# 63117
# 63110
# 63117
# 63143
# 63143
# 63119
# 63119
# 63116
# 63116
# 63144
# 63109
# 63108
# 63108
# 63108
# 63116
# 63108
# 63105
# 63116
# 63105

# %%
zip_count_df.dtypes
# Out:
# ZIP Code         object
# Liquor Stores     int64
# dtype: object

# %%
clean_zip_df.dtypes
# Out:
# ZIP Code              int64
# Crimes Committed    float64
# Population          float64
# dtype: object

# %%
zip_count_df['ZIP Code'] = zip_count_df['ZIP Code'].astype(int)
zip_count_df.dtypes
# Out:
# ZIP Code         int32
# Liquor Stores    int64
# dtype: object

# %%
zip_final_df = pd.merge(zip_count_df, clean_zip_df, on="ZIP Code", how="outer")
zip_final_df
# Out:
#     ZIP Code  Liquor Stores  Crimes Committed  Population
# 0      63101             34           15623.0      2620.0
# 1      63102             33             468.0      2316.0
# 2      63103             43             779.0      6900.0
# 3      63104             42             666.0     18656.0
# 4      63106             38             521.0     11883.0
# 5      63107             32             650.0     11912.0
# 6      63108             47             489.0     21568.0
# 7      63109             50             357.0     26946.0
# 8      63110             44             524.0     17107.0
# 9      63111             28             748.0     20313.0
# 10     63112             46             574.0     20368.0
# 11     63113             45             545.0     13167.0
# 12     63115             26             638.0     20775.0
# 13     63116             45            1156.0     43540.0
# 14     63118             48             989.0     26704.0
# 15     63120             17             429.0     10296.0
# 16     63139             50             302.0     22789.0
# 17     63147             15             859.0     11373.0

# %%
zip_final_df['Crimes per Person'] = zip_final_df['Crimes Committed'] / zip_final_df['Population']
zip_final_df['Crimes per Liquor Store'] = zip_final_df['Crimes Committed'] / zip_final_df['Liquor Stores']
zip_final_df
# Out:
#     ZIP Code  Liquor Stores  Crimes Committed  Population  Crimes per Person  \
# 0      63101             34           15623.0      2620.0           5.962977
# 1      63102             33             468.0      2316.0           0.202073
# 2      63103             43             779.0      6900.0           0.112899
# 3      63104             42             666.0     18656.0           0.035699
# 4      63106             38             521.0     11883.0           0.043844
# 5      63107             32             650.0     11912.0           0.054567
# 6      63108             47             489.0     21568.0           0.022672
# 7      63109             50             357.0     26946.0           0.013249
# 8      63110             44             524.0     17107.0           0.030631
# 9      63111             28             748.0     20313.0           0.036824
# 10     63112             46             574.0     20368.0           0.028181
# 11     63113             45             545.0     13167.0           0.041391
# 12     63115             26             638.0     20775.0           0.030710
# 13     63116             45            1156.0     43540.0           0.026550
# 14     63118             48             989.0     26704.0           0.037036
# 15     63120             17             429.0     10296.0           0.041667
# 16     63139             50             302.0     22789.0           0.013252
# 17     63147             15             859.0     11373.0           0.075530
#
#     Crimes per Liquor Store
# 0                459.500000
# 1                 14.181818
# 2                 18.116279
# 3                 15.857143
# 4                 13.710526
# 5                 20.312500
# 6                 10.404255
# 7                  7.140000
# 8                 11.909091
# 9                 26.714286
# 10                12.478261
# 11                12.111111
# 12                24.538462
# 13                25.688889
# 14                20.604167
# 15                25.235294
# 16                 6.040000
# 17                57.266667

# %%
### playing with ANOVA testing

liquor_stores = zip_final_df['Liquor Stores'].sum()
sum_crimes_person = zip_final_df['Crimes per Person'].sum()
ave_crimes_person = (zip_final_df['Crimes Committed'].sum()) / (zip_final_df['Population'].sum())
ave_crimes_person_mean = sum_crimes_person / 18
ave_pop = (zip_final_df['Population'].sum())/18
crimes_mean = zip_final_df['Crimes Committed'].mean()
crimes_median = zip_final_df['Crimes Committed'].median()
crime_sum = crime_mean = zip_final_df['Crimes Committed'].sum()
              
zip_final_df
# Out:
#     ZIP Code  Liquor Stores  Crimes Committed  Population  Crimes per Person  \
# 0      63101             34           15623.0      2620.0           5.962977
# 1      63102             33             468.0      2316.0           0.202073
# 2      63103             43             779.0      6900.0           0.112899
# 3      63104             42             666.0     18656.0           0.035699
# 4      63106             38             521.0     11883.0           0.043844
# 5      63107             32             650.0     11912.0           0.054567
# 6      63108             47             489.0     21568.0           0.022672
# 7      63109             50             357.0     26946.0           0.013249
# 8      63110             44             524.0     17107.0           0.030631
# 9      63111             28             748.0     20313.0           0.036824
# 10     63112             46             574.0     20368.0           0.028181
# 11     63113             45             545.0     13167.0           0.041391
# 12     63115             26             638.0     20775.0           0.030710
# 13     63116             45            1156.0     43540.0           0.026550
# 14     63118             48             989.0     26704.0           0.037036
# 15     63120             17             429.0     10296.0           0.041667
# 16     63139             50             302.0     22789.0           0.013252
# 17     63147             15             859.0     11373.0           0.075530
#
#     Crimes per Liquor Store
# 0                459.500000
# 1                 14.181818
# 2                 18.116279
# 3                 15.857143
# 4                 13.710526
# 5                 20.312500
# 6                 10.404255
# 7                  7.140000
# 8                 11.909091
# 9                 26.714286
# 10                12.478261
# 11                12.111111
# 12                24.538462
# 13                25.688889
# 14                20.604167
# 15                25.235294
# 16                 6.040000
# 17                57.266667

# %%
# Scatter Plot
x_axis = zip_final_df['Liquor Stores']
y_axis = zip_final_df['Crimes Committed']
min_stores = zip_final_df['Liquor Stores'].min()
max_stores = zip_final_df['Liquor Stores'].max()
min_crimes = zip_final_df['Crimes Committed'].min()
max_crimes = zip_final_df['Crimes Committed'].max()

#print(x_axis)
#print(y_axis)
#print(min_stores)
#print(max_stores)
#print(min_crimes)
#print(max_crimes)

plt.scatter(x_axis, y_axis, marker="o", facecolor="blue", 
            edgecolor="black", alpha=0.85, s=24)
plt.grid()
plt.title("Nbr of Crimes vs Nbr of Liquor Stores")
x_label = "Nbr of Liquor Stores"
y_label = "Nbr of Crimes"
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.xlim(min_stores-1, max_stores+1)
plt.ylim(min_crimes-1, max_crimes+1)

###

#Trendline in matplotlib
z = np.polyfit(x_axis, y_axis, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")


###

slope, intercept = np.polyfit(np.log(x_axis), np.log(y_axis), 1)
print(slope)

###


# Save Figure
plt.savefig("Crime_Liquor_Plot")

# Show plot - example
plt.show()
# Out:
# -0.22379180759453157

# %%
# a method to calculate r2

from sklearn.metrics import r2_score

coefficient_of_dermination = r2_score(y_axis, p(x_axis))
coefficient_of_dermination
# Out:
# 0.00924867351126879

# %%
zip_final_filter_df = zip_final_df
zip_final_filter_df = zip_final_filter_df[zip_final_filter_df['Crimes Committed']<=2000]

# Scatter Plot Crimes vs Liquor Stores Filtered
x_axis = zip_final_filter_df['Liquor Stores']
y_axis = zip_final_filter_df['Crimes Committed']
min_stores = zip_final_filter_df['Liquor Stores'].min()
max_stores = zip_final_filter_df['Liquor Stores'].max()
min_crimes = zip_final_filter_df['Crimes Committed'].min()
max_crimes = zip_final_filter_df['Crimes Committed'].max()

#print(x_axis)
#print(y_axis)
#print(min_stores)
#print(max_stores)
#print(min_crimes)
#print(max_crimes)

plt.scatter(x_axis, y_axis, marker="o", facecolor="blue", 
            edgecolor="black", alpha=0.85, s=24)
plt.grid()
plt.title("Nbr of Crimes vs Nbr of Liquor Stores")
x_label = "Nbr of Liquor Stores"
y_label = "Nbr of Crimes"
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.xlim(min_stores-1, max_stores+1)
plt.ylim(min_crimes-1, max_crimes+1)

###

#Trendline in matplotlib
z = np.polyfit(x_axis, y_axis, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")


###

slope, intercept = np.polyfit(np.log(x_axis), np.log(y_axis), 1)
print(slope)

###

# Save Figure
plt.savefig("Crime_Liquor_Filter_Plot")

# Show plot - example
plt.show()
# Out:
# -0.13504184790165788

# %%
# a method to calculate r2

coefficient_of_dermination = r2_score(y_axis, p(x_axis))
coefficient_of_dermination
# Out:
# 0.008320996825451399

# %%
# Scatter Plot Crimes vs All Population
x_axis = zip_final_df['Population']
y_axis = zip_final_df['Crimes Committed']
min_pop = zip_final_df['Population'].min()
max_pop = zip_final_df['Population'].max()
min_crimes = zip_final_df['Crimes Committed'].min()
max_crimes = zip_final_df['Crimes Committed'].max()

#print(x_axis)
#print(y_axis)
#print(min_stores)
#print(max_stores)
#print(min_crimes)
#print(max_crimes)

plt.scatter(x_axis, y_axis, marker="o", facecolor="blue", 
            edgecolor="black", alpha=0.85, s=24)
plt.grid()
plt.title("Nbr of Crimes vs Population")
x_label = "Zip Code Population"
y_label = "Nbr of Crimes"
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.xlim(min_pop-1, max_pop+1)
plt.ylim(min_crimes-1, max_crimes+1)

###

#Trendline in matplotlib
z = np.polyfit(x_axis, y_axis, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")


###

slope, intercept = np.polyfit(np.log(x_axis), np.log(y_axis), 1)
print(slope)

###

# Save Figure
plt.savefig("Crime_Pop_Plot")

# Show plot - example
plt.show()
# Out:
# -0.48117877294086153

# %%
# a method to calculate r2

coefficient_of_dermination = r2_score(y_axis, p(x_axis))
coefficient_of_dermination
# Out:
# 0.11786995705701675

# %%
# Scatter Plot Crimes vs Filtered Population
x_axis = zip_final_filter_df['Population']
y_axis = zip_final_filter_df['Crimes Committed']
min_pop = zip_final_filter_df['Population'].min()
max_pop = zip_final_filter_df['Population'].max()
min_crimes = zip_final_filter_df['Crimes Committed'].min()
max_crimes = zip_final_filter_df['Crimes Committed'].max()

#print(x_axis)
#print(y_axis)
#print(min_stores)
#print(max_stores)
#print(min_crimes)
#print(max_crimes)

plt.scatter(x_axis, y_axis, marker="o", facecolor="blue", 
            edgecolor="black", alpha=0.85, s=24)
plt.grid()
plt.title("Nbr of Crimes vs Population")
x_label = "Zip Code Population"
y_label = "Nbr of Crimes"
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.xlim(min_pop-1, max_pop+1)
plt.ylim(min_crimes-1, max_crimes+1)

###

#Trendline in matplotlib
z = np.polyfit(x_axis, y_axis, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")


###

slope, intercept = np.polyfit(np.log(x_axis), np.log(y_axis), 1)
print(slope)

###

# Save Figure
plt.savefig("Crime_Pop_Filter_Plot")

# Show plot - example
plt.show()
# Out:
# 0.10420696122535346

# %%
# a method to calculate r2

coefficient_of_dermination = r2_score(y_axis, p(x_axis))
coefficient_of_dermination
# Out:
# 0.17616261954463475

# %%
# Scatter Plot Liquor Stores vs Population
x_axis = zip_final_filter_df['Population']
y_axis = zip_final_filter_df['Liquor Stores']
min_pop = zip_final_filter_df['Population'].min()
max_pop = zip_final_filter_df['Population'].max()
min_crimes = zip_final_filter_df['Liquor Stores'].min()
max_crimes = zip_final_filter_df['Liquor Stores'].max()

#print(x_axis)
#print(y_axis)
#print(min_stores)
#print(max_stores)
#print(min_crimes)
#print(max_crimes)

plt.scatter(x_axis, y_axis, marker="o", facecolor="blue", 
            edgecolor="black", alpha=0.85, s=24)
plt.grid()
plt.title("Nbr of Liquor Stores vs Population")
x_label = "Zip Code Population"
y_label = "Nbr of Liquor Stores"
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.xlim(min_pop-1, max_pop+1)
plt.ylim(min_crimes-1, max_crimes+1)

###

#Trendline in matplotlib
z = np.polyfit(x_axis, y_axis, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")


###

slope, intercept = np.polyfit(np.log(x_axis), np.log(y_axis), 1)
print(slope)

###

# Save Figure
plt.savefig("Store_Pop_Plot")

# Show plot - example
plt.show()
# Out:
# 0.1906914186962775

# %%
# a method to calculate r2

coefficient_of_dermination = r2_score(y_axis, p(x_axis))
coefficient_of_dermination
# Out:
# 0.20438987170645162

# %%
# bar chart Liquor Stores vs Zip
zip_codes = "63101","63102","63103","63104","63106","63107","63108","63109","63110","63111","63112","63113","63115","63116","63118","63120","63139","63147"
x_axis = np.arange(len(zip_codes))
y_axis = zip_final_df['Liquor Stores']


plt.title("Nbr of Liquor Stores vs Zip Code")
x_label = "Zip Code"
y_label = "Nbr of Liquor Stores"
plt.xlabel(x_label)
plt.ylabel(y_label)

#plt.figure(figsize=(20,10))
plt.bar(zip_codes, y_axis, color='r', alpha=0.5, align="center")
plt.xticks(rotation=90)
plt.autoscale(enable=True, axis='x', tight=True)

###

#plt.text() , you need to give (x,y) location , where you want to put the numbers,
#So here index will give you x pos and data+1 will provide a little gap in y axis.
for index,data in enumerate(y_axis):
    plt.text(x=index , y =data+.2 , s=f"{data}" , horizontalalignment='center', fontdict=dict(fontsize=10))

plt.tight_layout()
###


# Save Figure
plt.savefig("Zip_Stores_Plot")

# Show plot - example
plt.show()

# %%
# bar chart Crimes vs Zip
zip_codes = "63101","63102","63103","63104","63106","63107","63108","63109","63110","63111","63112","63113","63115","63116","63118","63120","63139","63147"
x_axis = np.arange(len(zip_codes))
y_axis = zip_final_df['Crimes Committed']


plt.title("Nbr of Crimes vs Zip Code")
x_label = "Zip Code"
y_label = "Nbr of Crimes"
plt.xlabel(x_label)
plt.ylabel(y_label)

#plt.figure(figsize=(20,10))
plt.bar(zip_codes, y_axis, color='b', alpha=0.5, align="center")
plt.xticks(rotation=90)
plt.autoscale(enable=True, axis='x', tight=True)
plt.tight_layout()
# Save Figure
plt.savefig("Zip_Crime_Plot")

# Show plot - example
plt.show()

# %%
stl_crime_categories = pd.concat(map(pd.read_csv, glob.glob(os.path.join("vince-crime-data-8-29.csv"))))
stl_crime_categories.head(400)
# Out:
#     Final Classification  Complaint CodedMonth       DateOccur FlagCrime  \
# 0                Assault  18-039966    2019-01   8/24/18 21:54
# 1                Assault  18-047140    2019-01   10/3/18 18:30         Y
# 2                Assault  18-047140    2019-01   10/3/18 18:30         Y
# 3                Assault  18-057095    2019-01   12/2/18 17:38         Y
# 4                Assault  18-060487    2019-01  12/23/18 11:50         Y
# 5                Assault  19-000005    2019-01     1/1/19 0:01         Y
# 6                Assault  19-000008    2019-01     1/1/19 0:13         Y
# 7                Assault  19-000008    2019-01     1/1/19 0:13         Y
# 8                Assault  19-000019    2019-01     1/1/19 1:28         Y
# 9                Assault  19-000021    2019-01     1/1/19 1:31         Y
# 10               Assault  19-000021    2019-01     1/1/19 1:31         Y
# 11               Assault  19-000036    2019-01     1/1/19 2:55         Y
# 12               Assault  19-000060    2019-01     1/1/19 8:40         Y
# 13               Assault  19-000121    2019-01    1/1/19 15:03         Y
# 14               Assault  19-000148    2019-01    1/1/19 16:00         Y
# 15               Assault  19-000171    2019-01    1/1/19 23:07         Y
# 16               Assault  19-000171    2019-01    1/1/19 23:07         Y
# 17               Assault  19-000208    2019-01     1/2/19 9:25         Y
# 18               Assault  19-000208    2019-01     1/2/19 9:25         Y
# 19               Assault  19-000213    2019-01    1/2/19 10:10         Y
# 20               Assault  19-000270    2019-01    1/2/19 14:23         Y
# 21               Assault  19-000270    2019-01    1/2/19 14:23         Y
# 22               Assault  19-000332    2019-01    1/2/19 23:00         Y
# 23               Assault  19-000339    2019-01     1/3/19 2:04         Y
# 24               Assault  19-000339    2019-01     1/3/19 2:04         Y
# 25               Assault  19-000356    2019-01     1/3/19 2:10         Y
# 26               Assault  19-000559    2019-01    1/4/19 11:16         Y
# 27               Assault  19-000559    2019-01    1/4/19 11:16         Y
# 28               Assault  19-000559    2019-01    1/4/19 11:16         Y
# 29               Assault  19-000599    2019-01    1/4/19 15:30         Y
# ..                   ...        ...        ...             ...       ...
# 370              Assault  19-017037    2019-04    4/17/19 7:00         Y
# 371              Assault  19-017131    2019-04   4/17/19 18:18         Y
# 372              Assault  19-017131    2019-04   4/17/19 18:18         Y
# 373              Assault  19-017159    2019-04   4/17/19 20:00         Y
# 374              Assault  19-017431    2019-04   4/19/19 11:45         Y
# 375              Assault  19-017477    2019-04   4/19/19 16:39         Y
# 376              Assault  19-017545    2019-04    4/20/19 2:47         Y
# 377              Assault  19-017659    2019-04   4/20/19 22:15         Y
# 378              Assault  19-017801    2019-04   4/21/19 23:10         Y
# 379              Assault  19-017801    2019-04   4/21/19 23:10         Y
# 380              Assault  19-017950    2019-04   4/22/19 16:28         Y
# 381              Assault  19-018027    2019-04    4/23/19 0:35         Y
# 382              Assault  19-018027    2019-04    4/23/19 0:35         Y
# 383              Assault  19-018067    2019-04    4/23/19 8:10         Y
# 384              Assault  19-018235    2019-04   4/23/19 19:40         Y
# 385              Assault  19-018256    2019-04    4/24/19 1:46         Y
# 386              Assault  19-018438    2019-04   4/24/19 21:20         Y
# 387              Assault  19-019215    2019-04   4/26/19 16:00         Y
# 388              Assault  19-019215    2019-04   4/26/19 16:00         Y
# 389              Assault  19-018842    2019-05   4/26/19 19:30         Y
# 390              Assault  19-018871    2019-04    4/27/19 0:01         Y
# 391              Assault  19-019005    2019-04   4/27/19 19:04         Y
# 392              Assault  19-019014    2019-04   4/27/19 20:00         Y
# 393              Assault  19-019074    2019-04    4/28/19 8:10         Y
# 394              Assault  19-019122    2019-04   4/28/19 15:18         Y
# 395              Assault  19-019122    2019-04   4/28/19 15:18         Y
# 396              Assault  19-019122    2019-04   4/28/19 15:18         Y
# 397              Assault  19-019159    2019-04   4/28/19 21:00         Y
# 398              Assault  19-019158    2019-04   4/28/19 21:00         Y
# 399              Assault  19-019158    2019-04   4/28/19 21:00         Y
#
#     FlagUnfounded FlagAdministrative  Count FlagCleanup  Crime  ...  \
# 0                                        -1              41011  ...
# 1                                         1              41011  ...
# 2                                         1              41011  ...
# 3                                         1              41011  ...
# 4                                         1              41011  ...
# 5                                         1              41011  ...
# 6                                         1              41011  ...
# 7                                         1              41011  ...
# 8                                         1              41011  ...
# 9                                         1              41011  ...
# 10                                        1              41011  ...
# 11                                        1              41011  ...
# 12                                        1              41011  ...
# 13                                        1              41011  ...
# 14                                        1              41011  ...
# 15                                        1              41011  ...
# 16                                        1              41011  ...
# 17                                        1              41011  ...
# 18                                        1              41011  ...
# 19                                        1              41011  ...
# 20                                        1              41011  ...
# 21                                        1              41011  ...
# 22                                        1              41011  ...
# 23                                        1              41011  ...
# 24                                        1              41011  ...
# 25                                        1              41011  ...
# 26                                        1              41011  ...
# 27                                        1              41011  ...
# 28                                        1              41011  ...
# 29                                        1              41011  ...
# ..            ...                ...    ...         ...    ...  ...
# 370                                       1              41011  ...
# 371                                       1              41011  ...
# 372                                       1              41011  ...
# 373                                       1              41011  ...
# 374                                       1              41011  ...
# 375                                       1              41011  ...
# 376                                       1              41011  ...
# 377                                       1              41011  ...
# 378                                       1              41011  ...
# 379                                       1              41011  ...
# 380                                       1              41011  ...
# 381                                       1              41011  ...
# 382                                       1              41011  ...
# 383                                       1              41011  ...
# 384                                       1              41011  ...
# 385                                       1              41011  ...
# 386                                       1              41011  ...
# 387                                       1              41011  ...
# 388                                       1              41011  ...
# 389                                       1              41011  ...
# 390                                       1              41011  ...
# 391                                       1              41011  ...
# 392                                       1              41011  ...
# 393                                       1              41011  ...
# 394                                       1              41011  ...
# 395                                       1              41011  ...
# 396                                       1              41011  ...
# 397                                       1              41011  ...
# 398                                       1              41011  ...
# 399                                       1              41011  ...
#
#                 LocationName                       LocationComment CADAddress  \
# 0                                                                        5629
# 1                                                                        3661
# 2                                                                        3661
# 3                                                       4900 BLOCK
# 4                                                                       10800
# 5                                                                         713
# 6                                                                        3211
# 7                                                                        3211
# 8
# 9                                                                         721
# 10                                                                        721
# 11
# 12                                                                        851
# 13                                                       IN STREET       2933
# 14                                                                       4444
# 15                                                                       2051
# 16                                                                       2051
# 17                                                    INTERSECTION
# 18                                                    INTERSECTION
# 19                                                       IN STREET        660
# 20
# 21
# 22                                            IN FRONT OF LOCATION       8538
# 23                 RESIDENCE                                             2048
# 24                 RESIDENCE                                             2048
# 25                                                                       2102
# 26
# 27
# 28
# 29                                                      DOWNSTAIRS       4200
# ..                       ...                                   ...        ...
# 370                                                                      4727
# 371  PEABODY HOUSING COMPLEX
# 372  PEABODY HOUSING COMPLEX
# 373  CARONDOLET NEIGHBORHOOD                                              419
# 374                                                  ON THE STREET       4626
# 375
# 376
# 377
# 378
# 379
# 380
# 381          @BP GAS STATION                                             5421
# 382          @BP GAS STATION                                             5421
# 383
# 384                           AT INTERSECTION OF S KINGSHIGHWAY AN       5562
# 385                                                                      5590
# 386                                                                      8514
# 387                                                                      4114
# 388                                                                      4114
# 389                                                                      3214
# 390                                                   INTERSECTION       4949
# 391                                                          APT C       1114
# 392                                             INSIDE FOREST PARK
# 393                                                                      1936
# 394                                                           REAR       3840
# 395                                                           REAR       3840
# 396                                                           REAR       3840
# 397                                                                      3600
# 398                                                                      4560
# 399                                                                      4560
#
#            CADStreet  Unnamed: 19 state                       street address  \
# 0            ENRIGHT    St. Louis    MO          5629 ENRIGHT, St. Louis, MO
# 1           LIERMANN    St. Louis    MO         3661 LIERMANN, St. Louis, MO
# 2           LIERMANN    St. Louis    MO         3661 LIERMANN, St. Louis, MO
# 3                       St. Louis    MO                      , St. Louis, MO
# 4           LOOKAWAY    St. Louis    MO        10800 LOOKAWAY, St. Louis, MO
# 5             BIDDLE    St. Louis    MO            713 BIDDLE, St. Louis, MO
# 6         UNIVERSITY    St. Louis    MO       3211 UNIVERSITY, St. Louis, MO
# 7         UNIVERSITY    St. Louis    MO       3211 UNIVERSITY, St. Louis, MO
# 8                       St. Louis    MO                      , St. Louis, MO
# 9             TUCKER    St. Louis    MO            721 TUCKER, St. Louis, MO
# 10            TUCKER    St. Louis    MO            721 TUCKER, St. Louis, MO
# 11                      St. Louis    MO                      , St. Louis, MO
# 12        GOODFELLOW    St. Louis    MO        851 GOODFELLOW, St. Louis, MO
# 13            LOCUST    St. Louis    MO           2933 LOCUST, St. Louis, MO
# 14           PENROSE    St. Louis    MO          4444 PENROSE, St. Louis, MO
# 15           DE SOTO    St. Louis    MO          2051 DE SOTO, St. Louis, MO
# 16           DE SOTO    St. Louis    MO          2051 DE SOTO, St. Louis, MO
# 17                      St. Louis    MO                      , St. Louis, MO
# 18                      St. Louis    MO                      , St. Louis, MO
# 19          ROSEDALE    St. Louis    MO          660 ROSEDALE, St. Louis, MO
# 20                      St. Louis    MO                      , St. Louis, MO
# 21                      St. Louis    MO                      , St. Louis, MO
# 22          BROADWAY    St. Louis    MO         8538 BROADWAY, St. Louis, MO
# 23           DE SOTO    St. Louis    MO          2048 DE SOTO, St. Louis, MO
# 24           DE SOTO    St. Louis    MO          2048 DE SOTO, St. Louis, MO
# 25           PRAIRIE    St. Louis    MO          2102 PRAIRIE, St. Louis, MO
# 26                      St. Louis    MO                      , St. Louis, MO
# 27                      St. Louis    MO                      , St. Louis, MO
# 28                      St. Louis    MO                      , St. Louis, MO
# 29   COTE BRILLIANTE    St. Louis    MO  4200 COTE BRILLIANTE, St. Louis, MO
# ..               ...          ...   ...                                  ...
# 370           CARTER    St. Louis    MO           4727 CARTER, St. Louis, MO
# 371                     St. Louis    MO                      , St. Louis, MO
# 372                     St. Louis    MO                      , St. Louis, MO
# 373             MOTT    St. Louis    MO              419 MOTT, St. Louis, MO
# 374         VIRGINIA    St. Louis    MO         4626 VIRGINIA, St. Louis, MO
# 375                     St. Louis    MO                      , St. Louis, MO
# 376                     St. Louis    MO                      , St. Louis, MO
# 377                     St. Louis    MO                      , St. Louis, MO
# 378                     St. Louis    MO                      , St. Louis, MO
# 379                     St. Louis    MO                      , St. Louis, MO
# 380                     St. Louis    MO                      , St. Louis, MO
# 381           ORIOLE    St. Louis    MO           5421 ORIOLE, St. Louis, MO
# 382           ORIOLE    St. Louis    MO           5421 ORIOLE, St. Louis, MO
# 383                     St. Louis    MO                      , St. Louis, MO
# 384             PALM    St. Louis    MO             5562 PALM, St. Louis, MO
# 385       FLORISSANT    St. Louis    MO       5590 FLORISSANT, St. Louis, MO
# 386           LOWELL    St. Louis    MO           8514 LOWELL, St. Louis, MO
# 387          COMPTON    St. Louis    MO          4114 COMPTON, St. Louis, MO
# 388          COMPTON    St. Louis    MO          4114 COMPTON, St. Louis, MO
# 389            MIAMI    St. Louis    MO            3214 MIAMI, St. Louis, MO
# 390                     St. Louis    MO                4949  , St. Louis, MO
# 391             CARR    St. Louis    MO             1114 CARR, St. Louis, MO
# 392                     St. Louis    MO                      , St. Louis, MO
# 393             BELT    St. Louis    MO             1936 BELT, St. Louis, MO
# 394     EICHELBERGER    St. Louis    MO     3840 EICHELBERGER, St. Louis, MO
# 395     EICHELBERGER    St. Louis    MO     3840 EICHELBERGER, St. Louis, MO
# 396     EICHELBERGER    St. Louis    MO     3840 EICHELBERGER, St. Louis, MO
# 397         ARKANSAS    St. Louis    MO         3600 ARKANSAS, St. Louis, MO
# 398          EMERSON    St. Louis    MO          4560 EMERSON, St. Louis, MO
# 399          EMERSON    St. Louis    MO          4560 EMERSON, St. Louis, MO
#
#        Zip    XCoord     YCoord
# 0    63101  894650.3  1002194.0
# 1    63101  900676.3  1022101.0
# 2    63101  892933.4  1038924.0
# 3    63101  907024.3  1017619.0
# 4    63137  897445.8  1003246.0
# 5    63101  887231.2  1043366.0
# 6    63106       0.0        0.0
# 7    63106       0.0        0.0
# 8    63101  883184.1  1033624.0
# 9    63141  884675.9  1030679.0
# 10   63141  907212.4  1020338.0
# 11   63101  908201.1  1022280.0
# 12   63112  890079.4  1033431.0
# 13   63103  905327.5  1019532.0
# 14   63115  909758.9  1019796.0
# 15   63107       0.0        0.0
# 16   63107  877216.3  1006444.0
# 17   63101  895987.1  1018872.0
# 18   63101  899205.0  1020595.0
# 19   63112  906077.5  1028981.0
# 20   63101  877325.8  1026148.0
# 21   63101  882308.8  1030604.0
# 22   63147  900459.2  1038662.0
# 23   63107  893063.9  1039007.0
# 24   63107  888838.8   991787.5
# 25   63101  896261.1   997737.1
# 26   63101  901904.8  1003291.0
# 27   63101  885747.1  1003901.0
# 28   63101  888270.5   998142.6
# 29   63113  902912.3  1010464.0
# ..     ...       ...        ...
# 370  63115  896532.6  1005619.0
# 371  63101  877369.7  1007815.0
# 372  63101  895099.8  1008117.0
# 373  63141  885193.6  1037577.0
# 374  63111  893788.8  1005469.0
# 375  63101  888884.8  1036000.0
# 376  63101  893730.8  1001654.0
# 377  63101  893704.7  1002850.0
# 378  63101  893608.3  1000145.0
# 379  63101  893815.9  1004507.0
# 380  63101  894070.2  1006802.0
# 381  63120  896659.8  1004325.0
# 382  63120  894313.9  1008897.0
# 383  63101  893613.9  1004531.0
# 384  63120  893516.4  1004609.0
# 385  63120  895862.9  1018182.0
# 386  63147  893779.1  1007492.0
# 387  63101  892784.6  1002974.0
# 388  63101  891712.0   998693.9
# 389  63118  892842.6  1003662.0
# 390  63101  901069.3  1029712.0
# 391  63101  892317.3  1002049.0
# 392  63101  890012.1   996284.7
# 393  63101       0.0        0.0
# 394  63116  895417.8  1021428.0
# 395  63116  895417.8  1021428.0
# 396  63116  895417.8  1021428.0
# 397  63101  892751.6  1000910.0
# 398  63120  887049.4   992496.4
# 399  63120  893462.6  1003663.0
#
# [400 rows x 25 columns]

# %%
assault_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='Assault'].index)
assault_by_zip = assault_df["Zip"].value_counts()
assault_by_zip
assault_by_zip_df = assault_by_zip.rename_axis('Zip').reset_index(name='Assault Count')
assault_by_zip_df.head()
# Out:
#      Zip  Assault Count
# 0  63101           2431
# 1  63118            168
# 2  63116            148
# 3  63147            144
# 4  63113            132

# %%
arson_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='Arson'].index)
arson_df
arson_by_zip = arson_df["Zip"].value_counts()
arson_by_zip_df = arson_by_zip.rename_axis('Zip').reset_index(name='Arson Count')
arson_by_zip_df.head()
# Out:
#      Zip  Arson Count
# 0  63101           82
# 1  63113            8
# 2  63111            8
# 3  63107            7
# 4  63118            5

# %%
dui_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='DUI'].index)

dui_by_zip = dui_df["Zip"].value_counts()
dui_by_zip_df = dui_by_zip.rename_axis('Zip').reset_index(name='DUI Count')
dui_by_zip_df.head()
# Out:
#      Zip  DUI Count
# 0  63101         68
# 1  63110          3
# 2  63147          2
# 3  63125          2
# 4  63116          2

# %%
homicide_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='Homicide'].index)
homicide_by_zip = homicide_df["Zip"].value_counts()
homicide_by_zip_df = homicide_by_zip.rename_axis('Zip').reset_index(name='Homicide Count')
homicide_by_zip_df.head()
# Out:
#      Zip  Homicide Count
# 0  63101              82
# 1  63147               9
# 2  63120               6
# 3  63118               6
# 4  63111               5

# %%
possession_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='Liquor Possession by Minor'].index)
possession_by_zip = possession_df["Zip"].value_counts()
possession_by_zip_df = possession_by_zip.rename_axis('Zip').reset_index(name='Possession Count')
possession_by_zip_df
# Out:
#      Zip  Possession Count
# 0  63101                10
# 1  63104                 8
# 2  63102                 1
# 3  63117                 1

# %%
rape_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='Rape'].index)
rape_by_zip = rape_df["Zip"].value_counts()
rape_by_zip_df = rape_by_zip.rename_axis('Zip').reset_index(name='Rape Count')
rape_by_zip_df.head()
# Out:
#      Zip  Rape Count
# 0  63101          65
# 1  63103          13
# 2  63125          10
# 3  63104           5
# 4  63111           5

# %%
robbery_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='Robbery'].index)
robbery_by_zip = robbery_df["Zip"].value_counts()
robbery_by_zip_df = robbery_by_zip.rename_axis('Zip').reset_index(name='Robbery Count')
robbery_by_zip_df
# Out:
#       Zip  Robbery Count
# 0   63101            492
# 1   63118             35
# 2   63115             32
# 3   63107             32
# 4   63112             25
# 5   63147             23
# 6   63125             18
# 7   63116             18
# 8   63104             17
# 9   63106             17
# 10  63108             16
# 11  63111             14
# 12  63110             14
# 13  63120             13
# 14  63113             13
# 15  63103             11
# 16  63109              8
# 17  63102              7
# 18  63129              7
# 19  63138              5
# 20  63132              5
# 21  63143              4
# 22  63137              4
# 23  63139              4
# 24  63136              3
# 25  63134              3
# 26  63141              2
# 27  63044              2
# 28  63117              1
# 29  63144              1
# 30  63121              1
# 31  63123              1
# 32  63131              1

# %%
sex_crime_df = stl_crime_categories.drop(stl_crime_categories[stl_crime_categories
                                                            ['Final Classification']!='Sex Crime'].index)
sex_crime_by_zip = sex_crime_df["Zip"].value_counts()
sex_crime_by_zip_df = sex_crime_by_zip.rename_axis('Zip').reset_index(name='Sex Crime Count')
sex_crime_by_zip_df
# Out:
#       Zip  Sex Crime Count
# 0   63101               85
# 1   63103                9
# 2   63102                7
# 3   63104                7
# 4   63116                6
# 5   63147                4
# 6   63108                4
# 7   63125                3
# 8   63118                3
# 9   63113                3
# 10  63109                2
# 11  63106                2
# 12  63107                2
# 13  63111                2
# 14  63136                2
# 15  63110                1
# 16  63137                1
# 17  63115                1
# 18  63129                1
# 19  63132                1
# 20  63134                1
# 21  63031                1

# %%
merge_1 = pd.merge(assault_by_zip_df, arson_by_zip_df, on="Zip", how="outer")
merge_2 = pd.merge(merge_1, dui_by_zip_df, on="Zip", how="outer")
merge_3 = pd.merge(merge_2, homicide_by_zip_df, on="Zip",how="outer")
merge_4 = pd.merge(merge_3, possession_by_zip_df, on="Zip",how="outer")
merge_5 = pd.merge(merge_4, rape_by_zip_df, on="Zip",how="outer")
merge_6 = pd.merge(merge_5, robbery_by_zip_df, on="Zip",how="outer")
merge_7 = pd.merge(merge_6, sex_crime_by_zip_df, on="Zip",how="outer")
merge_7
merge_7[['Assault Count', 'Arson Count', 'DUI Count', 'Homicide Count', 
       'Possession Count', 'Rape Count', 'Robbery Count', 'Sex Crime Count']] = merge_7[['Assault Count', 'Arson Count', 'DUI Count', 'Homicide Count', 
       'Possession Count', 'Rape Count', 'Robbery Count', 'Sex Crime Count']].fillna(value= 0)
merge_7 = merge_7.rename(columns={'Zip': 'ZIP Code'})
merge_7
# Out:
#     ZIP Code  Assault Count  Arson Count  DUI Count  Homicide Count  \
# 0      63101         2431.0         82.0       68.0            82.0
# 1      63118          168.0          5.0        1.0             6.0
# 2      63116          148.0          2.0        2.0             3.0
# 3      63147          144.0          4.0        2.0             9.0
# 4      63113          132.0          8.0        0.0             4.0
# 5      63104          125.0          3.0        0.0             0.0
# 6      63106          121.0          2.0        0.0             1.0
# 7      63107          113.0          7.0        1.0             5.0
# 8      63120          104.0          3.0        0.0             6.0
# 9      63111           99.0          8.0        2.0             5.0
# 10     63115           97.0          2.0        0.0             2.0
# 11     63112           88.0          0.0        1.0             2.0
# 12     63103           84.0          0.0        0.0             0.0
# 13     63125           67.0          0.0        2.0             0.0
# 14     63102           56.0          0.0        1.0             1.0
# 15     63110           52.0          0.0        3.0             0.0
# 16     63108           46.0          2.0        0.0             1.0
# 17     63129           37.0          2.0        1.0             1.0
# 18     63132           32.0          0.0        0.0             1.0
# 19     63139           24.0          0.0        1.0             1.0
# 20     63109           22.0          0.0        0.0             1.0
# 21     63136           18.0          0.0        0.0             1.0
# 22     63137           14.0          3.0        0.0             0.0
# 23     63135            8.0          0.0        0.0             0.0
# 24     63141            7.0          0.0        0.0             0.0
# 25     63134            6.0          0.0        0.0             0.0
# 26     63122            6.0          0.0        0.0             0.0
# 27     63143            5.0          0.0        0.0             0.0
# 28     63130            4.0          0.0        0.0             0.0
# 29     63044            4.0          1.0        0.0             0.0
# 30     63123            3.0          0.0        0.0             0.0
# 31     63117            3.0          0.0        1.0             0.0
# 32     63119            2.0          0.0        0.0             0.0
# 33     63121            2.0          0.0        0.0             0.0
# 34     63138            2.0          0.0        0.0             0.0
# 35     63131            1.0          0.0        0.0             0.0
# 36     63133            1.0          0.0        0.0             0.0
# 37     63128            0.0          0.0        0.0             0.0
# 38     63144            0.0          0.0        0.0             0.0
# 39     63031            0.0          0.0        0.0             0.0
#
#     Possession Count  Rape Count  Robbery Count  Sex Crime Count
# 0               10.0        65.0          492.0             85.0
# 1                0.0         4.0           35.0              3.0
# 2                0.0         3.0           18.0              6.0
# 3                0.0         2.0           23.0              4.0
# 4                0.0         3.0           13.0              3.0
# 5                8.0         5.0           17.0              7.0
# 6                0.0         3.0           17.0              2.0
# 7                0.0         3.0           32.0              2.0
# 8                0.0         1.0           13.0              0.0
# 9                0.0         5.0           14.0              2.0
# 10               0.0         3.0           32.0              1.0
# 11               0.0         3.0           25.0              0.0
# 12               0.0        13.0           11.0              9.0
# 13               0.0        10.0           18.0              3.0
# 14               1.0         3.0            7.0              7.0
# 15               0.0         3.0           14.0              1.0
# 16               0.0         1.0           16.0              4.0
# 17               0.0         1.0            7.0              1.0
# 18               0.0         1.0            5.0              1.0
# 19               0.0         0.0            4.0              0.0
# 20               0.0         1.0            8.0              2.0
# 21               0.0         1.0            3.0              2.0
# 22               0.0         0.0            4.0              1.0
# 23               0.0         0.0            0.0              0.0
# 24               0.0         1.0            2.0              0.0
# 25               0.0         1.0            3.0              1.0
# 26               0.0         1.0            0.0              0.0
# 27               0.0         0.0            4.0              0.0
# 28               0.0         1.0            0.0              0.0
# 29               0.0         0.0            2.0              0.0
# 30               0.0         0.0            1.0              0.0
# 31               1.0         0.0            1.0              0.0
# 32               0.0         0.0            0.0              0.0
# 33               0.0         0.0            1.0              0.0
# 34               0.0         0.0            5.0              0.0
# 35               0.0         0.0            1.0              0.0
# 36               0.0         0.0            0.0              0.0
# 37               0.0         1.0            0.0              0.0
# 38               0.0         0.0            1.0              0.0
# 39               0.0         0.0            0.0              1.0

# %%
df_w_categories = pd.merge(zip_final_df, merge_7, on="ZIP Code", how="outer")
# df_w_categories2 = df_w_categories.drop(df_w_categories.loc[df_w_categories['Liquor Stores']=="NaN"].index, inplace=True)
df_w_categories.dropna()
# Out:
#     ZIP Code  Liquor Stores  Crimes Committed  Population  Crimes per Person  \
# 0      63101           34.0           15623.0      2620.0           5.962977
# 1      63102           33.0             468.0      2316.0           0.202073
# 2      63103           43.0             779.0      6900.0           0.112899
# 3      63104           42.0             666.0     18656.0           0.035699
# 4      63106           38.0             521.0     11883.0           0.043844
# 5      63107           32.0             650.0     11912.0           0.054567
# 6      63108           47.0             489.0     21568.0           0.022672
# 7      63109           50.0             357.0     26946.0           0.013249
# 8      63110           44.0             524.0     17107.0           0.030631
# 9      63111           28.0             748.0     20313.0           0.036824
# 10     63112           46.0             574.0     20368.0           0.028181
# 11     63113           45.0             545.0     13167.0           0.041391
# 12     63115           26.0             638.0     20775.0           0.030710
# 13     63116           45.0            1156.0     43540.0           0.026550
# 14     63118           48.0             989.0     26704.0           0.037036
# 15     63120           17.0             429.0     10296.0           0.041667
# 16     63139           50.0             302.0     22789.0           0.013252
# 17     63147           15.0             859.0     11373.0           0.075530
#
#     Crimes per Liquor Store  Assault Count  Arson Count  DUI Count  \
# 0                459.500000         2431.0         82.0       68.0
# 1                 14.181818           56.0          0.0        1.0
# 2                 18.116279           84.0          0.0        0.0
# 3                 15.857143          125.0          3.0        0.0
# 4                 13.710526          121.0          2.0        0.0
# 5                 20.312500          113.0          7.0        1.0
# 6                 10.404255           46.0          2.0        0.0
# 7                  7.140000           22.0          0.0        0.0
# 8                 11.909091           52.0          0.0        3.0
# 9                 26.714286           99.0          8.0        2.0
# 10                12.478261           88.0          0.0        1.0
# 11                12.111111          132.0          8.0        0.0
# 12                24.538462           97.0          2.0        0.0
# 13                25.688889          148.0          2.0        2.0
# 14                20.604167          168.0          5.0        1.0
# 15                25.235294          104.0          3.0        0.0
# 16                 6.040000           24.0          0.0        1.0
# 17                57.266667          144.0          4.0        2.0
#
#     Homicide Count  Possession Count  Rape Count  Robbery Count  \
# 0             82.0              10.0        65.0          492.0
# 1              1.0               1.0         3.0            7.0
# 2              0.0               0.0        13.0           11.0
# 3              0.0               8.0         5.0           17.0
# 4              1.0               0.0         3.0           17.0
# 5              5.0               0.0         3.0           32.0
# 6              1.0               0.0         1.0           16.0
# 7              1.0               0.0         1.0            8.0
# 8              0.0               0.0         3.0           14.0
# 9              5.0               0.0         5.0           14.0
# 10             2.0               0.0         3.0           25.0
# 11             4.0               0.0         3.0           13.0
# 12             2.0               0.0         3.0           32.0
# 13             3.0               0.0         3.0           18.0
# 14             6.0               0.0         4.0           35.0
# 15             6.0               0.0         1.0           13.0
# 16             1.0               0.0         0.0            4.0
# 17             9.0               0.0         2.0           23.0
#
#     Sex Crime Count
# 0              85.0
# 1               7.0
# 2               9.0
# 3               7.0
# 4               2.0
# 5               2.0
# 6               4.0
# 7               2.0
# 8               1.0
# 9               2.0
# 10              0.0
# 11              3.0
# 12              1.0
# 13              6.0
# 14              3.0
# 15              0.0
# 16              0.0
# 17              4.0

# %%
crime_summary_df = stl_crime_categories
crime_summary_df = crime_summary_df.groupby(['Final Classification']).size().reset_index(name='counts')
crime_summary_df
# Out:
#          Final Classification  counts
# 0                       Arson     134
# 1                     Assault    4276
# 2                         DUI      86
# 3                    Homicide     132
# 4  Liquor Possession by Minor      20
# 5                        Rape     139
# 6                     Robbery     849
# 7                   Sex Crime     148

# %%
# bar chart Types of Crimes
crime_types = "Arson","Assault","DUI","Homicide","Possession","Rape","Robbery","Sex Crime"
x_axis = crime_types
y_axis = crime_summary_df['counts']


plt.title("Types of Crimes")
x_label = "Type of Crime"
y_label = "Nbr of Times Committed"
plt.xlabel(x_label)
plt.ylabel(y_label)

#plt.figure(figsize=(20,10))
plt.bar(crime_types, y_axis, color='b', alpha=0.5, align="center")
plt.xticks(rotation=90)
plt.autoscale(enable=True, axis='x', tight=True)

###

#plt.text() , you need to give (x,y) location , where you want to put the numbers,
#So here index will give you x pos and data+1 will provide a little gap in y axis.
for index,data in enumerate(y_axis):
    plt.text(x=index , y =data+40 , s=f"{data}" , horizontalalignment='center', fontdict=dict(fontsize=10))

plt.tight_layout()
###

# Save Figure
plt.savefig("Crime_Types_Plot")

# Show plot - example
plt.show()
