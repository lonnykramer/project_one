# %%
import requests
import json

# Google developer API key
from config import yelpkey

# %%
#r=requests.get("https://api.yelp.com/v3/businesses/search", headers={"content-type":"Bearer"})

url = "https://api.yelp.com/v3/businesses/search"

zip_code = "63130"

params = {
    "Authorization": yelpkey,
    "location": zip_code,
    "term": "liquor_store"
}



response = requests.get(url, params=params, headers={"Authorization": f"Bearer {yelpkey}"})
response
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-7be0868ce2ba> in <module>
#      14
#      15 response = requests.get(url, params=params, headers={"Authorization": f"Bearer {yelpkey}"})
# ---> 16 response.head()
#
# AttributeError: 'Response' object has no attribute 'head'

# %%
data = response.json()
data
# Out:
# {'businesses': [{'id': '_oFf7iTMxT8hMheDh_hNdg',
#    'alias': 'the-wine-merchant-clayton',
#    'name': 'The Wine Merchant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/90OuCOFFuw_jGqGth1qC6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wine-merchant-clayton?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 20,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.650606, 'longitude': -90.337605},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7817 Forsyth Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Clayton',
#     'zip_code': '63105',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['7817 Forsyth Blvd', 'Clayton, MO 63105']},
#    'phone': '+13148636282',
#    'display_phone': '(314) 863-6282',
#    'distance': 2085.8782037144265},
#   {'id': 'v_JuiBi8TY9UE0LoWNJ6vw',
#    'alias': 'total-wine-and-more-brentwood',
#    'name': 'Total Wine & More',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/40Y88UWH2NfUt4GdR5qmVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/total-wine-and-more-brentwood?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 55,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'tobaccoshops', 'title': 'Tobacco Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.6261821399246, 'longitude': -90.341212},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '90 Brentwood Promenade Ct',
#     'address2': '',
#     'address3': None,
#     'city': 'Brentwood',
#     'zip_code': '63144',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['90 Brentwood Promenade Ct', 'Brentwood, MO 63144']},
#    'phone': '+13149633265',
#    'display_phone': '(314) 963-3265',
#    'distance': 4672.826759409905},
#   {'id': 'fPYggpOpQq33onQAvOpwcw',
#    'alias': 'craft-beer-cellar-clayton-clayton',
#    'name': 'Craft Beer Cellar Clayton',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uvfKx9eBTzfcxrd0FbqNMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/craft-beer-cellar-clayton-clayton?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 71,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.65235, 'longitude': -90.3418},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8113 Maryland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clayton',
#     'zip_code': '63105',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['8113 Maryland Ave', 'Clayton, MO 63105']},
#    'phone': '+13142222444',
#    'display_phone': '(314) 222-2444',
#    'distance': 2181.9927931670745},
#   {'id': 'Z6Z4SyiT2Pk56K_r6zScVQ',
#    'alias': 'arena-liquor-olivette',
#    'name': 'Arena Liquor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z01FNM0vJSbW7uSZK-Ylyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arena-liquor-olivette?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 5,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.6734466552734,
#     'longitude': -90.3881225585938},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9612A Olive Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Olivette',
#     'zip_code': '63132',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['9612A Olive Blvd', 'Olivette, MO 63132']},
#    'phone': '+13149830501',
#    'display_phone': '(314) 983-0501',
#    'distance': 5650.434649687901},
#   {'id': 'bBnIv9ZRWvEatpIB-vP9sw',
#    'alias': 'the-wine-and-cheese-place-saint-louis',
#    'name': 'The Wine & Cheese Place',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TqEwFWoffy9mMEivPW783Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wine-and-cheese-place-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 53,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.649883, 'longitude': -90.329452},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7435 Forsyth Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63105',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['7435 Forsyth Blvd', 'Saint Louis, MO 63105']},
#    'phone': '+13147278788',
#    'display_phone': '(314) 727-8788',
#    'distance': 1856.4795108802668},
#   {'id': 'aI9NheK7iAepD3tzh0I4iw',
#    'alias': 'rock-road-liquor-saint-louis',
#    'name': 'Rock Road Liquor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bZIblajQtAVQrGeQZ6a8Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rock-road-liquor-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 1,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.7414701, 'longitude': -90.4055561},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11453 St Charles Rock Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63044',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['11453 St Charles Rock Rd', 'Saint Louis, MO 63044']},
#    'phone': '+13147366752',
#    'display_phone': '(314) 736-6752',
#    'distance': 11055.002889674428},
#   {'id': 'eNplYNNQP9TIWVzejwIHow',
#    'alias': 'arena-liquor-saint-louis-2',
#    'name': 'Arena Liquor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tThc5A5XYn2CVGdeDO5HeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arena-liquor-saint-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 19,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.627872467041,
#     'longitude': -90.2877426147461},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1217 Hampton Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63139',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['1217 Hampton Ave', 'Saint Louis, MO 63139']},
#    'phone': '+13146456644',
#    'display_phone': '(314) 645-6644',
#    'distance': 5265.525781135542},
#   {'id': 'TDmcgUZFHC5EECpSxqfgkQ',
#    'alias': 'starrs-richmond-heights',
#    'name': 'Starrs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cvqHf20zUwSFv1_LscyQuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/starrs-richmond-heights?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 44,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'winetastingroom', 'title': 'Wine Tasting Room'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.63182, 'longitude': -90.31965},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1135 S Big Bend Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond Heights',
#     'zip_code': '63117',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['1135 S Big Bend Blvd', 'Richmond Heights, MO 63117']},
#    'phone': '+13147812345',
#    'display_phone': '(314) 781-2345',
#    'distance': 3824.510593059379},
#   {'id': 'MSVZaUMtfPr4q8lFsiu-Cg',
#    'alias': 'parkers-table-saint-louis-3',
#    'name': "Parker's Table",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xENxthz8i8b_NZAN3Tv6Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parkers-table-saint-louis-3?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 60,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.632946, 'longitude': -90.308952},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7118 Oakland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63117',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['7118 Oakland Ave', 'Saint Louis, MO 63117']},
#    'phone': '+13146452050',
#    'display_phone': '(314) 645-2050',
#    'distance': 3886.360532197487},
#   {'id': '1qgzLXUQcLDWi4yDie645A',
#    'alias': 'world-news-clayton',
#    'name': 'World News',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KH-qSbczvzsBCynYm2RJew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/world-news-clayton?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 10,
#    'categories': [{'alias': 'mags', 'title': 'Newspapers & Magazines'},
#     {'alias': 'convenience', 'title': 'Convenience Stores'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.6500355, 'longitude': -90.3380254},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4 S Central Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clayton',
#     'zip_code': '63105',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['4 S Central Ave', 'Clayton, MO 63105']},
#    'phone': '+13147266010',
#    'display_phone': '(314) 726-6010',
#    'distance': 2158.768837815993},
#   {'id': 'JaMZoosomwX7DDjkFOEo3g',
#    'alias': 'schnucks-richmond-center-saint-louis-2',
#    'name': 'Schnucks Richmond Center',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cbMHnZC7j18qk3SBdgWFBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schnucks-richmond-center-saint-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 80,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.6334256677434,
#     'longitude': -90.3149853054275},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6600 Clayton Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63117',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['6600 Clayton Rd', 'Saint Louis, MO 63117']},
#    'phone': '+13146440510',
#    'display_phone': '(314) 644-0510',
#    'distance': 3693.8912211927977},
#   {'id': 'LBBvTQNXwcH7IQPhpt1Pzw',
#    'alias': 'intoxicology-st-louis',
#    'name': 'Intoxicology',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EN6GqHUJ_vXTwWwlwquo3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/intoxicology-st-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 12,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.6269171104628,
#     'longitude': -90.257775709033},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4321 Manchester Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'St. Louis',
#     'zip_code': '63110',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['4321 Manchester Ave', 'St. Louis, MO 63110']},
#    'phone': '+13148333088',
#    'display_phone': '(314) 833-3088',
#    'distance': 7186.893845719406},
#   {'id': 'iuhnsFMO-7JZYP1-YPc-YA',
#    'alias': 'maplewood-liquor-saint-louis',
#    'name': 'Maplewood Liquor',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maplewood-liquor-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 3,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.6143226623535,
#     'longitude': -90.314338684082},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7203 Manchester Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63143',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['7203 Manchester Rd', 'Saint Louis, MO 63143']},
#    'phone': '+13146455731',
#    'display_phone': '(314) 645-5731',
#    'distance': 5799.405465749942},
#   {'id': 'EPiFB9rj-RXf8VHdpVV67A',
#    'alias': 'in-and-out-market-richmond-heights',
#    'name': 'In & Out Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oXKMVKVUaWpGfPlAVvbW8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/in-and-out-market-richmond-heights?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 16,
#    'categories': [{'alias': 'convenience', 'title': 'Convenience Stores'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.630621, 'longitude': -90.312564},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1133 Bellevue Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond Heights',
#     'zip_code': '63117',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['1133 Bellevue Ave', 'Richmond Heights, MO 63117']},
#    'phone': '+13146472696',
#    'display_phone': '(314) 647-2696',
#    'distance': 4044.8801951074292},
#   {'id': 'fVvlgMz91aQuFqa5d2RirA',
#    'alias': 'straubs-saint-louis',
#    'name': "Straub's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_z64hgaY9doygVyLMG2oTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/straubs-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 96,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.645457, 'longitude': -90.264367},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '302 N Kingshighway Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63108',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['302 N Kingshighway Blvd', 'Saint Louis, MO 63108']},
#    'phone': '+13143616646',
#    'display_phone': '(314) 361-6646',
#    'distance': 5636.966271856283},
#   {'id': 'mjXIEy_xVd36aJqj9L2gBw',
#    'alias': 'brennans-saint-louis-2',
#    'name': "Brennan's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ejghPAOXWAKQNvvaOgJZsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brennans-saint-louis-2?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 127,
#    'categories': [{'alias': 'tobaccoshops', 'title': 'Tobacco Shops'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.6447464269143,
#     'longitude': -90.2610676821567},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4659 Maryland Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Saint Louis',
#     'zip_code': '63108',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['4659 Maryland Ave', 'Saint Louis, MO 63108']},
#    'phone': '+13144974449',
#    'display_phone': '(314) 497-4449',
#    'distance': 5931.146533614563},
#   {'id': 'qQSscPMhk3frtSNilF1cGA',
#    'alias': 'vom-fass-maplewood',
#    'name': 'VOM FASS',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CzqL-ldFvbjQwWxHhwFZ7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vom-fass-maplewood?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 63,
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.6128768920898,
#     'longitude': -90.3176345825195},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7314 Manchester Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Maplewood',
#     'zip_code': '63143',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['7314 Manchester Rd', 'Maplewood, MO 63143']},
#    'phone': '+13149325262',
#    'display_phone': '(314) 932-5262',
#    'distance': 5911.715559970792},
#   {'id': 'ugRsDz1wCrDH_sqm9SZRiA',
#    'alias': 'a-and-z-package-liquor-saint-louis',
#    'name': 'A & Z Package Liquor',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-and-z-package-liquor-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 5,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 38.640347, 'longitude': -90.26129},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4571 Laclede Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63108',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['4571 Laclede Ave', 'Saint Louis, MO 63108']},
#    'phone': '+13143674014',
#    'display_phone': '(314) 367-4014',
#    'distance': 6124.921673487539},
#   {'id': '835ManedAS46DftlYQgDKQ',
#    'alias': 'one-stop-mini-mart-and-pkg-liquor-saint-louis',
#    'name': 'One-Stop Mini-Mart & Pkg Liquor',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-stop-mini-mart-and-pkg-liquor-saint-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 1,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.63871, 'longitude': -90.2232},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3110 Delmar Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Saint Louis',
#     'zip_code': '63103',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['3110 Delmar Blvd', 'Saint Louis, MO 63103']},
#    'phone': '+13145343110',
#    'display_phone': '(314) 534-3110',
#    'distance': 9238.140787298451},
#   {'id': 'mxz6YKVNVZvL3h0QzTQlZg',
#    'alias': 'schnucks-ladue-st-louis',
#    'name': 'Schnucks - Ladue',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z0cC-c1DNjCa7APqMmK5JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schnucks-ladue-st-louis?adjust_creative=8ybcfpKLlV0gElcpuZNUcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8ybcfpKLlV0gElcpuZNUcA',
#    'review_count': 38,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.65660333, 'longitude': -90.35437167},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8867 Ladue Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'St. Louis',
#     'zip_code': '63124',
#     'country': 'US',
#     'state': 'MO',
#     'display_address': ['8867 Ladue Rd', 'St. Louis, MO 63124']},
#    'phone': '+13147257574',
#    'display_phone': '(314) 725-7574',
#    'distance': 2847.3707472080837}],
#  'total': 59,
#  'region': {'center': {'longitude': -90.3237533569336,
#    'latitude': 38.66593224838519}}}
